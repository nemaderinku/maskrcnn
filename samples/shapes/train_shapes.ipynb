# %% [markdown]
# # Mask R-CNN - Train on Shapes Dataset
#
#
# This notebook shows how to train Mask R-CNN on your own dataset. To keep things simple we use a synthetic dataset of shapes (squares, triangles, and circles) which enables fast training. You'd still need a GPU, though, because the network backbone is a Resnet101, which would be too slow to train on a CPU. On a GPU, you can start to get okay-ish results in a few minutes, and good results in less than an hour.
#
# The code of the *Shapes* dataset is included below. It generates images on the fly, so it doesn't require downloading any data. And it can generate images of any size, so we pick a small image size to train faster.

# %%
import os
import sys
import random
import math
import re
import time
import numpy as np
import cv2
import matplotlib
import matplotlib.pyplot as plt

# Root directory of the project
ROOT_DIR = os.path.abspath("../../")

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn.config import Config
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
from mrcnn.model import log

# %matplotlib inline 

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)

# %% [markdown]
# ## Configurations

# %%
class ShapesConfig(Config):
    """Configuration for training on the toy shapes dataset.
    Derives from the base Config class and overrides values specific
    to the toy shapes dataset.
    """
    # Give the configuration a recognizable name
    NAME = "shapes"

    # Train on 1 GPU and 8 images per GPU. We can put multiple images on each
    # GPU because the images are small. Batch size is 8 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 8

    # Number of classes (including background)
    NUM_CLASSES = 1 + 3  # background + 3 shapes

    # Use small images for faster training. Set the limits of the small side
    # the large side, and that determines the image shape.
    IMAGE_MIN_DIM = 128
    IMAGE_MAX_DIM = 128

    # Use smaller anchors because our image and objects are small
    RPN_ANCHOR_SCALES = (8, 16, 32, 64, 128)  # anchor side in pixels

    # Reduce training ROIs per image because the images are small and have
    # few objects. Aim to allow ROI sampling to pick 33% positive ROIs.
    TRAIN_ROIS_PER_IMAGE = 32

    # Use a small epoch since the data is simple
    STEPS_PER_EPOCH = 100

    # use small validation steps since the epoch is small
    VALIDATION_STEPS = 5
    
config = ShapesConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     8
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 8
# IMAGE_CHANNEL                  3
# IMAGE_MAX_DIM                  128
# IMAGE_META_SIZE                16
# IMAGE_MIN_DIM                  128
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [128 128   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0, 'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           shapes
# NUM_CLASSES                    4
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (8, 16, 32, 64, 128)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                100
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               5
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# ## Notebook Preferences

# %%
def get_ax(rows=1, cols=1, size=8):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.
    
    Change the default size attribute to control the size
    of rendered images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax

# %% [markdown]
# ## Dataset
#
# Create a synthetic dataset
#
# Extend the Dataset class and add a method to load the shapes dataset, `load_shapes()`, and override the following methods:
#
# * load_image()
# * load_mask()
# * image_reference()

# %%
class ShapesDataset(utils.Dataset):
    """Generates the shapes synthetic dataset. The dataset consists of simple
    shapes (triangles, squares, circles) placed randomly on a blank surface.
    The images are generated on the fly. No file access required.
    """

    def load_shapes(self, count, height, width):
        """Generate the requested number of synthetic images.
        count: number of images to generate.
        height, width: the size of the generated images.
        """
        # Add classes
        self.add_class("shapes", 1, "square")
        self.add_class("shapes", 2, "circle")
        self.add_class("shapes", 3, "triangle")

        # Add images
        # Generate random specifications of images (i.e. color and
        # list of shapes sizes and locations). This is more compact than
        # actual images. Images are generated on the fly in load_image().
        for i in range(count):
            bg_color, shapes = self.random_image(height, width)
            self.add_image("shapes", image_id=i, path=None,
                           width=width, height=height,
                           bg_color=bg_color, shapes=shapes)

    def load_image(self, image_id):
        """Generate an image from the specs of the given image ID.
        Typically this function loads the image from a file, but
        in this case it generates the image on the fly from the
        specs in image_info.
        """
        info = self.image_info[image_id]
        bg_color = np.array(info['bg_color']).reshape([1, 1, 3])
        image = np.ones([info['height'], info['width'], 3], dtype=np.uint8)
        image = image * bg_color.astype(np.uint8)
        for shape, color, dims in info['shapes']:
            image = self.draw_shape(image, shape, dims, color)
        return image

    def image_reference(self, image_id):
        """Return the shapes data of the image."""
        info = self.image_info[image_id]
        if info["source"] == "shapes":
            return info["shapes"]
        else:
            super(self.__class__).image_reference(self, image_id)

    def load_mask(self, image_id):
        """Generate instance masks for shapes of the given image ID.
        """
        info = self.image_info[image_id]
        shapes = info['shapes']
        count = len(shapes)
        mask = np.zeros([info['height'], info['width'], count], dtype=np.uint8)
        for i, (shape, _, dims) in enumerate(info['shapes']):
            mask[:, :, i:i+1] = self.draw_shape(mask[:, :, i:i+1].copy(),
                                                shape, dims, 1)
        # Handle occlusions
        occlusion = np.logical_not(mask[:, :, -1]).astype(np.uint8)
        for i in range(count-2, -1, -1):
            mask[:, :, i] = mask[:, :, i] * occlusion
            occlusion = np.logical_and(occlusion, np.logical_not(mask[:, :, i]))
        # Map class names to class IDs.
        class_ids = np.array([self.class_names.index(s[0]) for s in shapes])
        return mask.astype(np.bool), class_ids.astype(np.int32)

    def draw_shape(self, image, shape, dims, color):
        """Draws a shape from the given specs."""
        # Get the center x, y and the size s
        x, y, s = dims
        if shape == 'square':
            cv2.rectangle(image, (x-s, y-s), (x+s, y+s), color, -1)
        elif shape == "circle":
            cv2.circle(image, (x, y), s, color, -1)
        elif shape == "triangle":
            points = np.array([[(x, y-s),
                                (x-s/math.sin(math.radians(60)), y+s),
                                (x+s/math.sin(math.radians(60)), y+s),
                                ]], dtype=np.int32)
            cv2.fillPoly(image, points, color)
        return image

    def random_shape(self, height, width):
        """Generates specifications of a random shape that lies within
        the given height and width boundaries.
        Returns a tuple of three valus:
        * The shape name (square, circle, ...)
        * Shape color: a tuple of 3 values, RGB.
        * Shape dimensions: A tuple of values that define the shape size
                            and location. Differs per shape type.
        """
        # Shape
        shape = random.choice(["square", "circle", "triangle"])
        # Color
        color = tuple([random.randint(0, 255) for _ in range(3)])
        # Center x, y
        buffer = 20
        y = random.randint(buffer, height - buffer - 1)
        x = random.randint(buffer, width - buffer - 1)
        # Size
        s = random.randint(buffer, height//4)
        return shape, color, (x, y, s)

    def random_image(self, height, width):
        """Creates random specifications of an image with multiple shapes.
        Returns the background color of the image and a list of shape
        specifications that can be used to draw the image.
        """
        # Pick random background color
        bg_color = np.array([random.randint(0, 255) for _ in range(3)])
        # Generate a few random shapes and record their
        # bounding boxes
        shapes = []
        boxes = []
        N = random.randint(1, 4)
        for _ in range(N):
            shape, color, dims = self.random_shape(height, width)
            shapes.append((shape, color, dims))
            x, y, s = dims
            boxes.append([y-s, x-s, y+s, x+s])
        # Apply non-max suppression wit 0.3 threshold to avoid
        # shapes covering each other
        keep_ixs = utils.non_max_suppression(np.array(boxes), np.arange(N), 0.3)
        shapes = [s for i, s in enumerate(shapes) if i in keep_ixs]
        return bg_color, shapes

# %%
# Training dataset
dataset_train = ShapesDataset()
dataset_train.load_shapes(500, config.IMAGE_SHAPE[0], config.IMAGE_SHAPE[1])
dataset_train.prepare()

# Validation dataset
dataset_val = ShapesDataset()
dataset_val.load_shapes(50, config.IMAGE_SHAPE[0], config.IMAGE_SHAPE[1])
dataset_val.prepare()

# %%
# Load and display random samples
image_ids = np.random.choice(dataset_train.image_ids, 4)
for image_id in image_ids:
    image = dataset_train.load_image(image_id)
    mask, class_ids = dataset_train.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset_train.class_names)

# %% [markdown]
# ## Ceate Model

# %%
# Create model in training mode
model = modellib.MaskRCNN(mode="training", config=config,
                          model_dir=MODEL_DIR)

# %%
# Which weights to start with?
init_with = "coco"  # imagenet, coco, or last

if init_with == "imagenet":
    model.load_weights(model.get_imagenet_weights(), by_name=True)
elif init_with == "coco":
    # Load weights trained on MS COCO, but skip layers that
    # are different due to the different number of classes
    # See README for instructions to download the COCO weights
    model.load_weights(COCO_MODEL_PATH, by_name=True,
                       exclude=["mrcnn_class_logits", "mrcnn_bbox_fc", 
                                "mrcnn_bbox", "mrcnn_mask"])
elif init_with == "last":
    # Load the last model you trained and continue training
    model.load_weights(model.find_last(), by_name=True)

# %% [markdown]
# ## Training
#
# Train in two stages:
# 1. Only the heads. Here we're freezing all the backbone layers and training only the randomly initialized layers (i.e. the ones that we didn't use pre-trained weights from MS COCO). To train only the head layers, pass `layers='heads'` to the `train()` function.
#
# 2. Fine-tune all layers. For this simple example it's not necessary, but we're including it to show the process. Simply pass `layers="all` to train all layers.

# %%
# Train the head branches
# Passing layers="heads" freezes all layers except the head
# layers. You can also pass a regular expression to select
# which layers to train by name pattern.
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=1, 
            layers='heads')
# Out:
# Starting at epoch 1. LR=0.001
#
# Checkpoint Path: /models/Mask_RCNN/logs/shapes20180830T0227/mask_rcnn_shapes_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/gradients_impl.py:108: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.5/dist-packages/keras/engine/training_generator.py:46: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the`keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'

# %%
# Fine tune all layers
# Passing layers="all" trains all layers. You can also 
# pass a regular expression to select which layers to
# train by name pattern.
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE / 10,
            epochs=200, 
            layers="all")
# Out:
# Starting at epoch 1. LR=0.0001
#
# Checkpoint Path: /models/Mask_RCNN/logs/shapes20180830T0227/mask_rcnn_shapes_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res4g_branch2a         (Conv2D)
# bn4g_branch2a          (BatchNorm)
# res4g_branch2b         (Conv2D)
# bn4g_branch2b          (BatchNorm)
# res4g_branch2c         (Conv2D)
# bn4g_branch2c          (BatchNorm)
# res4h_branch2a         (Conv2D)
# bn4h_branch2a          (BatchNorm)
# res4h_branch2b         (Conv2D)
# bn4h_branch2b          (BatchNorm)
# res4h_branch2c         (Conv2D)
# bn4h_branch2c          (BatchNorm)
# res4i_branch2a         (Conv2D)
# bn4i_branch2a          (BatchNorm)
# res4i_branch2b         (Conv2D)
# bn4i_branch2b          (BatchNorm)
# res4i_branch2c         (Conv2D)
# bn4i_branch2c          (BatchNorm)
# res4j_branch2a         (Conv2D)
# bn4j_branch2a          (BatchNorm)
# res4j_branch2b         (Conv2D)
# bn4j_branch2b          (BatchNorm)
# res4j_branch2c         (Conv2D)
# bn4j_branch2c          (BatchNorm)
# res4k_branch2a         (Conv2D)
# bn4k_branch2a          (BatchNorm)
# res4k_branch2b         (Conv2D)
# bn4k_branch2b          (BatchNorm)
# res4k_branch2c         (Conv2D)
# bn4k_branch2c          (BatchNorm)
# res4l_branch2a         (Conv2D)
# bn4l_branch2a          (BatchNorm)
# res4l_branch2b         (Conv2D)
# bn4l_branch2b          (BatchNorm)
# res4l_branch2c         (Conv2D)
# bn4l_branch2c          (BatchNorm)
# res4m_branch2a         (Conv2D)
# bn4m_branch2a          (BatchNorm)
# res4m_branch2b         (Conv2D)
# bn4m_branch2b          (BatchNorm)
# res4m_branch2c         (Conv2D)
# bn4m_branch2c          (BatchNorm)
# res4n_branch2a         (Conv2D)
# bn4n_branch2a          (BatchNorm)
# res4n_branch2b         (Conv2D)
# bn4n_branch2b          (BatchNorm)
# res4n_branch2c         (Conv2D)
# bn4n_branch2c          (BatchNorm)
# res4o_branch2a         (Conv2D)
# bn4o_branch2a          (BatchNorm)
# res4o_branch2b         (Conv2D)
# bn4o_branch2b          (BatchNorm)
# res4o_branch2c         (Conv2D)
# bn4o_branch2c          (BatchNorm)
# res4p_branch2a         (Conv2D)
# bn4p_branch2a          (BatchNorm)
# res4p_branch2b         (Conv2D)
# bn4p_branch2b          (BatchNorm)
# res4p_branch2c         (Conv2D)
# bn4p_branch2c          (BatchNorm)
# res4q_branch2a         (Conv2D)
# bn4q_branch2a          (BatchNorm)
# res4q_branch2b         (Conv2D)
# bn4q_branch2b          (BatchNorm)
# res4q_branch2c         (Conv2D)
# bn4q_branch2c          (BatchNorm)
# res4r_branch2a         (Conv2D)
# bn4r_branch2a          (BatchNorm)
# res4r_branch2b         (Conv2D)
# bn4r_branch2b          (BatchNorm)
# res4r_branch2c         (Conv2D)
# bn4r_branch2c          (BatchNorm)
# res4s_branch2a         (Conv2D)
# bn4s_branch2a          (BatchNorm)
# res4s_branch2b         (Conv2D)
# bn4s_branch2b          (BatchNorm)
# res4s_branch2c         (Conv2D)
# bn4s_branch2c          (BatchNorm)
# res4t_branch2a         (Conv2D)
# bn4t_branch2a          (BatchNorm)
# res4t_branch2b         (Conv2D)
# bn4t_branch2b          (BatchNorm)
# res4t_branch2c         (Conv2D)
# bn4t_branch2c          (BatchNorm)
# res4u_branch2a         (Conv2D)
# bn4u_branch2a          (BatchNorm)
# res4u_branch2b         (Conv2D)
# bn4u_branch2b          (BatchNorm)
# res4u_branch2c         (Conv2D)
# bn4u_branch2c          (BatchNorm)
# res4v_branch2a         (Conv2D)
# bn4v_branch2a          (BatchNorm)
# res4v_branch2b         (Conv2D)
# bn4v_branch2b          (BatchNorm)
# res4v_branch2c         (Conv2D)
# bn4v_branch2c          (BatchNorm)
# res4w_branch2a         (Conv2D)
# bn4w_branch2a          (BatchNorm)
# res4w_branch2b         (Conv2D)
# bn4w_branch2b          (BatchNorm)
# res4w_branch2c         (Conv2D)
# bn4w_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/gradients_impl.py:108: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.5/dist-packages/keras/engine/training_generator.py:46: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the`keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 2/200
# 100/100 [==============================] - 75s 753ms/step - loss: 0.6341 - rpn_class_loss: 0.0126 - rpn_bbox_loss: 0.3672 - mrcnn_class_loss: 0.1059 - mrcnn_bbox_loss: 0.0590 - mrcnn_mask_loss: 0.0893 - val_loss: 0.7108 - val_rpn_class_loss: 0.0129 - val_rpn_bbox_loss: 0.4112 - val_mrcnn_class_loss: 0.1195 - val_mrcnn_bbox_loss: 0.0708 - val_mrcnn_mask_loss: 0.0964
# Epoch 3/200
# 100/100 [==============================] - 44s 442ms/step - loss: 0.6261 - rpn_class_loss: 0.0128 - rpn_bbox_loss: 0.3668 - mrcnn_class_loss: 0.1026 - mrcnn_bbox_loss: 0.0561 - mrcnn_mask_loss: 0.0878 - val_loss: 0.6640 - val_rpn_class_loss: 0.0098 - val_rpn_bbox_loss: 0.3763 - val_mrcnn_class_loss: 0.1181 - val_mrcnn_bbox_loss: 0.0694 - val_mrcnn_mask_loss: 0.0903
# Epoch 4/200
# 100/100 [==============================] - 45s 445ms/step - loss: 0.5973 - rpn_class_loss: 0.0122 - rpn_bbox_loss: 0.3543 - mrcnn_class_loss: 0.0975 - mrcnn_bbox_loss: 0.0520 - mrcnn_mask_loss: 0.0813 - val_loss: 0.6671 - val_rpn_class_loss: 0.0127 - val_rpn_bbox_loss: 0.3628 - val_mrcnn_class_loss: 0.1097 - val_mrcnn_bbox_loss: 0.0726 - val_mrcnn_mask_loss: 0.1093
# Epoch 5/200
# 100/100 [==============================] - 44s 442ms/step - loss: 0.5689 - rpn_class_loss: 0.0126 - rpn_bbox_loss: 0.3359 - mrcnn_class_loss: 0.0930 - mrcnn_bbox_loss: 0.0488 - mrcnn_mask_loss: 0.0786 - val_loss: 0.7913 - val_rpn_class_loss: 0.0153 - val_rpn_bbox_loss: 0.4538 - val_mrcnn_class_loss: 0.1313 - val_mrcnn_bbox_loss: 0.0787 - val_mrcnn_mask_loss: 0.1122
# Epoch 6/200
# 100/100 [==============================] - 44s 442ms/step - loss: 0.5445 - rpn_class_loss: 0.0118 - rpn_bbox_loss: 0.3205 - mrcnn_class_loss: 0.0907 - mrcnn_bbox_loss: 0.0466 - mrcnn_mask_loss: 0.0748 - val_loss: 0.7629 - val_rpn_class_loss: 0.0149 - val_rpn_bbox_loss: 0.4773 - val_mrcnn_class_loss: 0.0996 - val_mrcnn_bbox_loss: 0.0752 - val_mrcnn_mask_loss: 0.0959
# Epoch 7/200
# 100/100 [==============================] - 44s 440ms/step - loss: 0.5199 - rpn_class_loss: 0.0124 - rpn_bbox_loss: 0.3058 - mrcnn_class_loss: 0.0876 - mrcnn_bbox_loss: 0.0431 - mrcnn_mask_loss: 0.0710 - val_loss: 0.6463 - val_rpn_class_loss: 0.0116 - val_rpn_bbox_loss: 0.4279 - val_mrcnn_class_loss: 0.0863 - val_mrcnn_bbox_loss: 0.0450 - val_mrcnn_mask_loss: 0.0755
# Epoch 8/200
# 100/100 [==============================] - 44s 440ms/step - loss: 0.4912 - rpn_class_loss: 0.0121 - rpn_bbox_loss: 0.2835 - mrcnn_class_loss: 0.0826 - mrcnn_bbox_loss: 0.0425 - mrcnn_mask_loss: 0.0705 - val_loss: 0.6925 - val_rpn_class_loss: 0.0139 - val_rpn_bbox_loss: 0.3644 - val_mrcnn_class_loss: 0.1255 - val_mrcnn_bbox_loss: 0.0812 - val_mrcnn_mask_loss: 0.1075
# Epoch 9/200
# 100/100 [==============================] - 44s 439ms/step - loss: 0.4874 - rpn_class_loss: 0.0119 - rpn_bbox_loss: 0.2782 - mrcnn_class_loss: 0.0848 - mrcnn_bbox_loss: 0.0417 - mrcnn_mask_loss: 0.0708 - val_loss: 0.8148 - val_rpn_class_loss: 0.0122 - val_rpn_bbox_loss: 0.4422 - val_mrcnn_class_loss: 0.1345 - val_mrcnn_bbox_loss: 0.0901 - val_mrcnn_mask_loss: 0.1359
# Epoch 10/200
# 100/100 [==============================] - 44s 442ms/step - loss: 0.4522 - rpn_class_loss: 0.0116 - rpn_bbox_loss: 0.2454 - mrcnn_class_loss: 0.0796 - mrcnn_bbox_loss: 0.0419 - mrcnn_mask_loss: 0.0737 - val_loss: 0.5966 - val_rpn_class_loss: 0.0101 - val_rpn_bbox_loss: 0.3227 - val_mrcnn_class_loss: 0.1060 - val_mrcnn_bbox_loss: 0.0749 - val_mrcnn_mask_loss: 0.0828
# Epoch 11/200
# 100/100 [==============================] - 44s 438ms/step - loss: 0.4222 - rpn_class_loss: 0.0112 - rpn_bbox_loss: 0.2310 - mrcnn_class_loss: 0.0766 - mrcnn_bbox_loss: 0.0381 - mrcnn_mask_loss: 0.0653 - val_loss: 0.6350 - val_rpn_class_loss: 0.0135 - val_rpn_bbox_loss: 0.3445 - val_mrcnn_class_loss: 0.1278 - val_mrcnn_bbox_loss: 0.0651 - val_mrcnn_mask_loss: 0.0840
# Epoch 12/200
# 100/100 [==============================] - 44s 439ms/step - loss: 0.4297 - rpn_class_loss: 0.0110 - rpn_bbox_loss: 0.2294 - mrcnn_class_loss: 0.0800 - mrcnn_bbox_loss: 0.0403 - mrcnn_mask_loss: 0.0690 - val_loss: 0.5345 - val_rpn_class_loss: 0.0121 - val_rpn_bbox_loss: 0.2931 - val_mrcnn_class_loss: 0.0881 - val_mrcnn_bbox_loss: 0.0702 - val_mrcnn_mask_loss: 0.0710
# Epoch 13/200
# 100/100 [==============================] - 44s 436ms/step - loss: 0.4044 - rpn_class_loss: 0.0110 - rpn_bbox_loss: 0.2118 - mrcnn_class_loss: 0.0767 - mrcnn_bbox_loss: 0.0374 - mrcnn_mask_loss: 0.0674 - val_loss: 0.5604 - val_rpn_class_loss: 0.0105 - val_rpn_bbox_loss: 0.3467 - val_mrcnn_class_loss: 0.0842 - val_mrcnn_bbox_loss: 0.0528 - val_mrcnn_mask_loss: 0.0662
# Epoch 14/200
# 100/100 [==============================] - 44s 440ms/step - loss: 0.3785 - rpn_class_loss: 0.0116 - rpn_bbox_loss: 0.1887 - mrcnn_class_loss: 0.0752 - mrcnn_bbox_loss: 0.0377 - mrcnn_mask_loss: 0.0652 - val_loss: 0.4880 - val_rpn_class_loss: 0.0105 - val_rpn_bbox_loss: 0.2630 - val_mrcnn_class_loss: 0.0928 - val_mrcnn_bbox_loss: 0.0505 - val_mrcnn_mask_loss: 0.0714
# Epoch 15/200
# 100/100 [==============================] - 44s 437ms/step - loss: 0.3605 - rpn_class_loss: 0.0112 - rpn_bbox_loss: 0.1775 - mrcnn_class_loss: 0.0736 - mrcnn_bbox_loss: 0.0353 - mrcnn_mask_loss: 0.0630 - val_loss: 0.7682 - val_rpn_class_loss: 0.0141 - val_rpn_bbox_loss: 0.4441 - val_mrcnn_class_loss: 0.1029 - val_mrcnn_bbox_loss: 0.0885 - val_mrcnn_mask_loss: 0.1187
# Epoch 16/200
# 100/100 [==============================] - 44s 437ms/step - loss: 0.3514 - rpn_class_loss: 0.0110 - rpn_bbox_loss: 0.1698 - mrcnn_class_loss: 0.0720 - mrcnn_bbox_loss: 0.0355 - mrcnn_mask_loss: 0.0631 - val_loss: 0.4938 - val_rpn_class_loss: 0.0119 - val_rpn_bbox_loss: 0.2625 - val_mrcnn_class_loss: 0.0945 - val_mrcnn_bbox_loss: 0.0572 - val_mrcnn_mask_loss: 0.0677
# Epoch 17/200
# 100/100 [==============================] - 44s 438ms/step - loss: 0.3417 - rpn_class_loss: 0.0110 - rpn_bbox_loss: 0.1582 - mrcnn_class_loss: 0.0718 - mrcnn_bbox_loss: 0.0353 - mrcnn_mask_loss: 0.0654 - val_loss: 0.5363 - val_rpn_class_loss: 0.0111 - val_rpn_bbox_loss: 0.2949 - val_mrcnn_class_loss: 0.0871 - val_mrcnn_bbox_loss: 0.0570 - val_mrcnn_mask_loss: 0.0861
# Epoch 18/200
# 100/100 [==============================] - 44s 436ms/step - loss: 0.3174 - rpn_class_loss: 0.0104 - rpn_bbox_loss: 0.1452 - mrcnn_class_loss: 0.0683 - mrcnn_bbox_loss: 0.0328 - mrcnn_mask_loss: 0.0608 - val_loss: 0.6387 - val_rpn_class_loss: 0.0122 - val_rpn_bbox_loss: 0.3687 - val_mrcnn_class_loss: 0.0892 - val_mrcnn_bbox_loss: 0.0687 - val_mrcnn_mask_loss: 0.0999
# Epoch 19/200
# 100/100 [==============================] - 44s 437ms/step - loss: 0.3165 - rpn_class_loss: 0.0107 - rpn_bbox_loss: 0.1371 - mrcnn_class_loss: 0.0715 - mrcnn_bbox_loss: 0.0337 - mrcnn_mask_loss: 0.0636 - val_loss: 0.5539 - val_rpn_class_loss: 0.0141 - val_rpn_bbox_loss: 0.3279 - val_mrcnn_class_loss: 0.0832 - val_mrcnn_bbox_loss: 0.0566 - val_mrcnn_mask_loss: 0.0721
# Epoch 20/200
# 100/100 [==============================] - 44s 435ms/step - loss: 0.3005 - rpn_class_loss: 0.0107 - rpn_bbox_loss: 0.1319 - mrcnn_class_loss: 0.0646 - mrcnn_bbox_loss: 0.0321 - mrcnn_mask_loss: 0.0613 - val_loss: 0.5852 - val_rpn_class_loss: 0.0112 - val_rpn_bbox_loss: 0.2952 - val_mrcnn_class_loss: 0.0911 - val_mrcnn_bbox_loss: 0.0770 - val_mrcnn_mask_loss: 0.1108
# Epoch 21/200
# 100/100 [==============================] - 44s 438ms/step - loss: 0.2828 - rpn_class_loss: 0.0099 - rpn_bbox_loss: 0.1153 - mrcnn_class_loss: 0.0649 - mrcnn_bbox_loss: 0.0317 - mrcnn_mask_loss: 0.0610 - val_loss: 0.7395 - val_rpn_class_loss: 0.0140 - val_rpn_bbox_loss: 0.3950 - val_mrcnn_class_loss: 0.1336 - val_mrcnn_bbox_loss: 0.0937 - val_mrcnn_mask_loss: 0.1032
# Epoch 22/200
# 100/100 [==============================] - 44s 437ms/step - loss: 0.2658 - rpn_class_loss: 0.0096 - rpn_bbox_loss: 0.1051 - mrcnn_class_loss: 0.0631 - mrcnn_bbox_loss: 0.0300 - mrcnn_mask_loss: 0.0580 - val_loss: 0.5225 - val_rpn_class_loss: 0.0121 - val_rpn_bbox_loss: 0.3051 - val_mrcnn_class_loss: 0.0890 - val_mrcnn_bbox_loss: 0.0589 - val_mrcnn_mask_loss: 0.0573
# Epoch 23/200
# 100/100 [==============================] - 44s 438ms/step - loss: 0.2625 - rpn_class_loss: 0.0103 - rpn_bbox_loss: 0.1012 - mrcnn_class_loss: 0.0624 - mrcnn_bbox_loss: 0.0304 - mrcnn_mask_loss: 0.0584 - val_loss: 0.4555 - val_rpn_class_loss: 0.0086 - val_rpn_bbox_loss: 0.2040 - val_mrcnn_class_loss: 0.0858 - val_mrcnn_bbox_loss: 0.0678 - val_mrcnn_mask_loss: 0.0893
# Epoch 24/200
# 100/100 [==============================] - 44s 436ms/step - loss: 0.2536 - rpn_class_loss: 0.0092 - rpn_bbox_loss: 0.0923 - mrcnn_class_loss: 0.0616 - mrcnn_bbox_loss: 0.0304 - mrcnn_mask_loss: 0.0601 - val_loss: 0.5717 - val_rpn_class_loss: 0.0085 - val_rpn_bbox_loss: 0.2857 - val_mrcnn_class_loss: 0.1160 - val_mrcnn_bbox_loss: 0.0637 - val_mrcnn_mask_loss: 0.0978
# Epoch 25/200
# 100/100 [==============================] - 44s 436ms/step - loss: 0.2362 - rpn_class_loss: 0.0094 - rpn_bbox_loss: 0.0852 - mrcnn_class_loss: 0.0583 - mrcnn_bbox_loss: 0.0272 - mrcnn_mask_loss: 0.0561 - val_loss: 0.6394 - val_rpn_class_loss: 0.0094 - val_rpn_bbox_loss: 0.2952 - val_mrcnn_class_loss: 0.0939 - val_mrcnn_bbox_loss: 0.0872 - val_mrcnn_mask_loss: 0.1538
# Epoch 26/200
# 100/100 [==============================] - 43s 434ms/step - loss: 0.2463 - rpn_class_loss: 0.0094 - rpn_bbox_loss: 0.0866 - mrcnn_class_loss: 0.0624 - mrcnn_bbox_loss: 0.0289 - mrcnn_mask_loss: 0.0589 - val_loss: 0.6040 - val_rpn_class_loss: 0.0109 - val_rpn_bbox_loss: 0.3082 - val_mrcnn_class_loss: 0.0965 - val_mrcnn_bbox_loss: 0.0849 - val_mrcnn_mask_loss: 0.1034
# Epoch 27/200
# 100/100 [==============================] - 43s 434ms/step - loss: 0.2336 - rpn_class_loss: 0.0095 - rpn_bbox_loss: 0.0788 - mrcnn_class_loss: 0.0592 - mrcnn_bbox_loss: 0.0279 - mrcnn_mask_loss: 0.0582 - val_loss: 0.5143 - val_rpn_class_loss: 0.0099 - val_rpn_bbox_loss: 0.2656 - val_mrcnn_class_loss: 0.0918 - val_mrcnn_bbox_loss: 0.0618 - val_mrcnn_mask_loss: 0.0852
# Epoch 28/200
# 100/100 [==============================] - 44s 436ms/step - loss: 0.2277 - rpn_class_loss: 0.0091 - rpn_bbox_loss: 0.0742 - mrcnn_class_loss: 0.0597 - mrcnn_bbox_loss: 0.0274 - mrcnn_mask_loss: 0.0573 - val_loss: 0.4780 - val_rpn_class_loss: 0.0084 - val_rpn_bbox_loss: 0.2609 - val_mrcnn_class_loss: 0.0859 - val_mrcnn_bbox_loss: 0.0520 - val_mrcnn_mask_loss: 0.0708
# Epoch 29/200
# 100/100 [==============================] - 44s 435ms/step - loss: 0.2145 - rpn_class_loss: 0.0087 - rpn_bbox_loss: 0.0708 - mrcnn_class_loss: 0.0564 - mrcnn_bbox_loss: 0.0246 - mrcnn_mask_loss: 0.0540 - val_loss: 0.4976 - val_rpn_class_loss: 0.0096 - val_rpn_bbox_loss: 0.2346 - val_mrcnn_class_loss: 0.0631 - val_mrcnn_bbox_loss: 0.0702 - val_mrcnn_mask_loss: 0.1200
# Epoch 30/200
# 100/100 [==============================] - 44s 438ms/step - loss: 0.2056 - rpn_class_loss: 0.0090 - rpn_bbox_loss: 0.0625 - mrcnn_class_loss: 0.0549 - mrcnn_bbox_loss: 0.0246 - mrcnn_mask_loss: 0.0545 - val_loss: 0.5497 - val_rpn_class_loss: 0.0116 - val_rpn_bbox_loss: 0.3288 - val_mrcnn_class_loss: 0.0835 - val_mrcnn_bbox_loss: 0.0583 - val_mrcnn_mask_loss: 0.0674
# Epoch 31/200
# 100/100 [==============================] - 43s 434ms/step - loss: 0.2114 - rpn_class_loss: 0.0087 - rpn_bbox_loss: 0.0611 - mrcnn_class_loss: 0.0559 - mrcnn_bbox_loss: 0.0271 - mrcnn_mask_loss: 0.0585 - val_loss: 0.5020 - val_rpn_class_loss: 0.0081 - val_rpn_bbox_loss: 0.2756 - val_mrcnn_class_loss: 0.0802 - val_mrcnn_bbox_loss: 0.0539 - val_mrcnn_mask_loss: 0.0842
# Epoch 32/200
# 100/100 [==============================] - 43s 434ms/step - loss: 0.2018 - rpn_class_loss: 0.0085 - rpn_bbox_loss: 0.0587 - mrcnn_class_loss: 0.0541 - mrcnn_bbox_loss: 0.0253 - mrcnn_mask_loss: 0.0551 - val_loss: 0.4968 - val_rpn_class_loss: 0.0101 - val_rpn_bbox_loss: 0.2719 - val_mrcnn_class_loss: 0.0894 - val_mrcnn_bbox_loss: 0.0587 - val_mrcnn_mask_loss: 0.0667
# Epoch 33/200
# 100/100 [==============================] - 43s 434ms/step - loss: 0.1896 - rpn_class_loss: 0.0083 - rpn_bbox_loss: 0.0518 - mrcnn_class_loss: 0.0510 - mrcnn_bbox_loss: 0.0243 - mrcnn_mask_loss: 0.0541 - val_loss: 0.4956 - val_rpn_class_loss: 0.0108 - val_rpn_bbox_loss: 0.2770 - val_mrcnn_class_loss: 0.0733 - val_mrcnn_bbox_loss: 0.0578 - val_mrcnn_mask_loss: 0.0768
# Epoch 34/200
# 100/100 [==============================] - 43s 434ms/step - loss: 0.1962 - rpn_class_loss: 0.0083 - rpn_bbox_loss: 0.0527 - mrcnn_class_loss: 0.0530 - mrcnn_bbox_loss: 0.0250 - mrcnn_mask_loss: 0.0572 - val_loss: 0.5292 - val_rpn_class_loss: 0.0108 - val_rpn_bbox_loss: 0.3181 - val_mrcnn_class_loss: 0.0906 - val_mrcnn_bbox_loss: 0.0561 - val_mrcnn_mask_loss: 0.0536
# Epoch 35/200
# 100/100 [==============================] - 43s 430ms/step - loss: 0.1839 - rpn_class_loss: 0.0079 - rpn_bbox_loss: 0.0468 - mrcnn_class_loss: 0.0512 - mrcnn_bbox_loss: 0.0234 - mrcnn_mask_loss: 0.0545 - val_loss: 0.5280 - val_rpn_class_loss: 0.0112 - val_rpn_bbox_loss: 0.2720 - val_mrcnn_class_loss: 0.0905 - val_mrcnn_bbox_loss: 0.0611 - val_mrcnn_mask_loss: 0.0931
# Epoch 36/200
# 100/100 [==============================] - 43s 433ms/step - loss: 0.1827 - rpn_class_loss: 0.0081 - rpn_bbox_loss: 0.0477 - mrcnn_class_loss: 0.0515 - mrcnn_bbox_loss: 0.0230 - mrcnn_mask_loss: 0.0524 - val_loss: 0.6311 - val_rpn_class_loss: 0.0094 - val_rpn_bbox_loss: 0.2958 - val_mrcnn_class_loss: 0.1234 - val_mrcnn_bbox_loss: 0.0853 - val_mrcnn_mask_loss: 0.1173
# Epoch 37/200
# 100/100 [==============================] - 43s 433ms/step - loss: 0.1766 - rpn_class_loss: 0.0078 - rpn_bbox_loss: 0.0422 - mrcnn_class_loss: 0.0501 - mrcnn_bbox_loss: 0.0227 - mrcnn_mask_loss: 0.0538 - val_loss: 0.5019 - val_rpn_class_loss: 0.0084 - val_rpn_bbox_loss: 0.2654 - val_mrcnn_class_loss: 0.0645 - val_mrcnn_bbox_loss: 0.0574 - val_mrcnn_mask_loss: 0.1061
# Epoch 38/200
# 100/100 [==============================] - 43s 431ms/step - loss: 0.1720 - rpn_class_loss: 0.0080 - rpn_bbox_loss: 0.0392 - mrcnn_class_loss: 0.0492 - mrcnn_bbox_loss: 0.0224 - mrcnn_mask_loss: 0.0532 - val_loss: 0.6084 - val_rpn_class_loss: 0.0127 - val_rpn_bbox_loss: 0.4019 - val_mrcnn_class_loss: 0.0765 - val_mrcnn_bbox_loss: 0.0519 - val_mrcnn_mask_loss: 0.0654
# Epoch 39/200
# 100/100 [==============================] - 43s 431ms/step - loss: 0.1705 - rpn_class_loss: 0.0080 - rpn_bbox_loss: 0.0405 - mrcnn_class_loss: 0.0467 - mrcnn_bbox_loss: 0.0221 - mrcnn_mask_loss: 0.0532 - val_loss: 0.5567 - val_rpn_class_loss: 0.0113 - val_rpn_bbox_loss: 0.3452 - val_mrcnn_class_loss: 0.0851 - val_mrcnn_bbox_loss: 0.0543 - val_mrcnn_mask_loss: 0.0608
# Epoch 40/200
# 100/100 [==============================] - 43s 432ms/step - loss: 0.1664 - rpn_class_loss: 0.0077 - rpn_bbox_loss: 0.0378 - mrcnn_class_loss: 0.0473 - mrcnn_bbox_loss: 0.0215 - mrcnn_mask_loss: 0.0521 - val_loss: 0.5691 - val_rpn_class_loss: 0.0095 - val_rpn_bbox_loss: 0.3637 - val_mrcnn_class_loss: 0.0625 - val_mrcnn_bbox_loss: 0.0571 - val_mrcnn_mask_loss: 0.0763
# Epoch 41/200
# 100/100 [==============================] - 43s 433ms/step - loss: 0.1596 - rpn_class_loss: 0.0078 - rpn_bbox_loss: 0.0328 - mrcnn_class_loss: 0.0459 - mrcnn_bbox_loss: 0.0212 - mrcnn_mask_loss: 0.0519 - val_loss: 0.6025 - val_rpn_class_loss: 0.0103 - val_rpn_bbox_loss: 0.3742 - val_mrcnn_class_loss: 0.0967 - val_mrcnn_bbox_loss: 0.0473 - val_mrcnn_mask_loss: 0.0740
# Epoch 42/200
# 100/100 [==============================] - 43s 430ms/step - loss: 0.1580 - rpn_class_loss: 0.0073 - rpn_bbox_loss: 0.0318 - mrcnn_class_loss: 0.0456 - mrcnn_bbox_loss: 0.0206 - mrcnn_mask_loss: 0.0526 - val_loss: 0.5427 - val_rpn_class_loss: 0.0103 - val_rpn_bbox_loss: 0.2938 - val_mrcnn_class_loss: 0.0942 - val_mrcnn_bbox_loss: 0.0624 - val_mrcnn_mask_loss: 0.0820
# Epoch 43/200
# 100/100 [==============================] - 43s 433ms/step - loss: 0.1559 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.0300 - mrcnn_class_loss: 0.0447 - mrcnn_bbox_loss: 0.0204 - mrcnn_mask_loss: 0.0533 - val_loss: 0.4295 - val_rpn_class_loss: 0.0057 - val_rpn_bbox_loss: 0.2174 - val_mrcnn_class_loss: 0.0765 - val_mrcnn_bbox_loss: 0.0476 - val_mrcnn_mask_loss: 0.0823
# Epoch 44/200
# 100/100 [==============================] - 43s 432ms/step - loss: 0.1463 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.0281 - mrcnn_class_loss: 0.0416 - mrcnn_bbox_loss: 0.0193 - mrcnn_mask_loss: 0.0504 - val_loss: 0.4805 - val_rpn_class_loss: 0.0093 - val_rpn_bbox_loss: 0.2578 - val_mrcnn_class_loss: 0.0749 - val_mrcnn_bbox_loss: 0.0631 - val_mrcnn_mask_loss: 0.0754
# Epoch 45/200
# 100/100 [==============================] - 43s 433ms/step - loss: 0.1517 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.0307 - mrcnn_class_loss: 0.0438 - mrcnn_bbox_loss: 0.0196 - mrcnn_mask_loss: 0.0506 - val_loss: 0.3563 - val_rpn_class_loss: 0.0077 - val_rpn_bbox_loss: 0.2161 - val_mrcnn_class_loss: 0.0495 - val_mrcnn_bbox_loss: 0.0360 - val_mrcnn_mask_loss: 0.0470
# Epoch 46/200
# 100/100 [==============================] - 43s 432ms/step - loss: 0.1449 - rpn_class_loss: 0.0070 - rpn_bbox_loss: 0.0243 - mrcnn_class_loss: 0.0439 - mrcnn_bbox_loss: 0.0197 - mrcnn_mask_loss: 0.0501 - val_loss: 0.6460 - val_rpn_class_loss: 0.0098 - val_rpn_bbox_loss: 0.3332 - val_mrcnn_class_loss: 0.1334 - val_mrcnn_bbox_loss: 0.0717 - val_mrcnn_mask_loss: 0.0980
# Epoch 47/200
# 100/100 [==============================] - 43s 431ms/step - loss: 0.1475 - rpn_class_loss: 0.0066 - rpn_bbox_loss: 0.0281 - mrcnn_class_loss: 0.0430 - mrcnn_bbox_loss: 0.0191 - mrcnn_mask_loss: 0.0507 - val_loss: 0.6563 - val_rpn_class_loss: 0.0098 - val_rpn_bbox_loss: 0.3331 - val_mrcnn_class_loss: 0.1305 - val_mrcnn_bbox_loss: 0.0745 - val_mrcnn_mask_loss: 0.1082
# Epoch 48/200
# 100/100 [==============================] - 43s 429ms/step - loss: 0.1446 - rpn_class_loss: 0.0066 - rpn_bbox_loss: 0.0247 - mrcnn_class_loss: 0.0442 - mrcnn_bbox_loss: 0.0190 - mrcnn_mask_loss: 0.0500 - val_loss: 0.5973 - val_rpn_class_loss: 0.0137 - val_rpn_bbox_loss: 0.3847 - val_mrcnn_class_loss: 0.1003 - val_mrcnn_bbox_loss: 0.0449 - val_mrcnn_mask_loss: 0.0537
# Epoch 49/200
# 100/100 [==============================] - 43s 430ms/step - loss: 0.1485 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.0252 - mrcnn_class_loss: 0.0448 - mrcnn_bbox_loss: 0.0201 - mrcnn_mask_loss: 0.0515 - val_loss: 0.6857 - val_rpn_class_loss: 0.0115 - val_rpn_bbox_loss: 0.3433 - val_mrcnn_class_loss: 0.1168 - val_mrcnn_bbox_loss: 0.0842 - val_mrcnn_mask_loss: 0.1299
# Epoch 50/200
# 100/100 [==============================] - 43s 432ms/step - loss: 0.1311 - rpn_class_loss: 0.0068 - rpn_bbox_loss: 0.0211 - mrcnn_class_loss: 0.0384 - mrcnn_bbox_loss: 0.0171 - mrcnn_mask_loss: 0.0477 - val_loss: 0.5567 - val_rpn_class_loss: 0.0081 - val_rpn_bbox_loss: 0.3043 - val_mrcnn_class_loss: 0.0790 - val_mrcnn_bbox_loss: 0.0681 - val_mrcnn_mask_loss: 0.0971
# Epoch 51/200
# 100/100 [==============================] - 43s 432ms/step - loss: 0.1384 - rpn_class_loss: 0.0068 - rpn_bbox_loss: 0.0233 - mrcnn_class_loss: 0.0405 - mrcnn_bbox_loss: 0.0179 - mrcnn_mask_loss: 0.0499 - val_loss: 0.5038 - val_rpn_class_loss: 0.0102 - val_rpn_bbox_loss: 0.3265 - val_mrcnn_class_loss: 0.0758 - val_mrcnn_bbox_loss: 0.0355 - val_mrcnn_mask_loss: 0.0559
# Epoch 52/200
# 100/100 [==============================] - 43s 433ms/step - loss: 0.1352 - rpn_class_loss: 0.0066 - rpn_bbox_loss: 0.0226 - mrcnn_class_loss: 0.0388 - mrcnn_bbox_loss: 0.0180 - mrcnn_mask_loss: 0.0493 - val_loss: 0.7083 - val_rpn_class_loss: 0.0089 - val_rpn_bbox_loss: 0.3491 - val_mrcnn_class_loss: 0.0978 - val_mrcnn_bbox_loss: 0.0860 - val_mrcnn_mask_loss: 0.1665
# Epoch 53/200
# 100/100 [==============================] - 43s 432ms/step - loss: 0.1327 - rpn_class_loss: 0.0062 - rpn_bbox_loss: 0.0208 - mrcnn_class_loss: 0.0387 - mrcnn_bbox_loss: 0.0178 - mrcnn_mask_loss: 0.0491 - val_loss: 0.5792 - val_rpn_class_loss: 0.0088 - val_rpn_bbox_loss: 0.3056 - val_mrcnn_class_loss: 0.0879 - val_mrcnn_bbox_loss: 0.0699 - val_mrcnn_mask_loss: 0.1071
# Epoch 54/200
# 100/100 [==============================] - 43s 431ms/step - loss: 0.1376 - rpn_class_loss: 0.0065 - rpn_bbox_loss: 0.0176 - mrcnn_class_loss: 0.0427 - mrcnn_bbox_loss: 0.0195 - mrcnn_mask_loss: 0.0513 - val_loss: 0.5636 - val_rpn_class_loss: 0.0113 - val_rpn_bbox_loss: 0.3329 - val_mrcnn_class_loss: 0.0868 - val_mrcnn_bbox_loss: 0.0539 - val_mrcnn_mask_loss: 0.0787
# Epoch 55/200
# 100/100 [==============================] - 43s 434ms/step - loss: 0.1306 - rpn_class_loss: 0.0064 - rpn_bbox_loss: 0.0190 - mrcnn_class_loss: 0.0395 - mrcnn_bbox_loss: 0.0177 - mrcnn_mask_loss: 0.0481 - val_loss: 0.5211 - val_rpn_class_loss: 0.0092 - val_rpn_bbox_loss: 0.3102 - val_mrcnn_class_loss: 0.0953 - val_mrcnn_bbox_loss: 0.0504 - val_mrcnn_mask_loss: 0.0560
# Epoch 56/200
# 100/100 [==============================] - 43s 433ms/step - loss: 0.1320 - rpn_class_loss: 0.0062 - rpn_bbox_loss: 0.0197 - mrcnn_class_loss: 0.0399 - mrcnn_bbox_loss: 0.0177 - mrcnn_mask_loss: 0.0486 - val_loss: 0.4986 - val_rpn_class_loss: 0.0079 - val_rpn_bbox_loss: 0.2795 - val_mrcnn_class_loss: 0.0956 - val_mrcnn_bbox_loss: 0.0549 - val_mrcnn_mask_loss: 0.0607
# Epoch 57/200
# 100/100 [==============================] - 43s 433ms/step - loss: 0.1307 - rpn_class_loss: 0.0059 - rpn_bbox_loss: 0.0183 - mrcnn_class_loss: 0.0393 - mrcnn_bbox_loss: 0.0175 - mrcnn_mask_loss: 0.0498 - val_loss: 0.5729 - val_rpn_class_loss: 0.0069 - val_rpn_bbox_loss: 0.2940 - val_mrcnn_class_loss: 0.0828 - val_mrcnn_bbox_loss: 0.0597 - val_mrcnn_mask_loss: 0.1296
# Epoch 58/200
# 100/100 [==============================] - 43s 431ms/step - loss: 0.1244 - rpn_class_loss: 0.0057 - rpn_bbox_loss: 0.0172 - mrcnn_class_loss: 0.0360 - mrcnn_bbox_loss: 0.0168 - mrcnn_mask_loss: 0.0487 - val_loss: 0.7077 - val_rpn_class_loss: 0.0097 - val_rpn_bbox_loss: 0.3989 - val_mrcnn_class_loss: 0.1048 - val_mrcnn_bbox_loss: 0.0812 - val_mrcnn_mask_loss: 0.1130
# Epoch 59/200
# 100/100 [==============================] - 43s 431ms/step - loss: 0.1254 - rpn_class_loss: 0.0059 - rpn_bbox_loss: 0.0165 - mrcnn_class_loss: 0.0376 - mrcnn_bbox_loss: 0.0169 - mrcnn_mask_loss: 0.0484 - val_loss: 0.6017 - val_rpn_class_loss: 0.0059 - val_rpn_bbox_loss: 0.2996 - val_mrcnn_class_loss: 0.0881 - val_mrcnn_bbox_loss: 0.0814 - val_mrcnn_mask_loss: 0.1267
# Epoch 60/200
# 100/100 [==============================] - 43s 432ms/step - loss: 0.1241 - rpn_class_loss: 0.0059 - rpn_bbox_loss: 0.0145 - mrcnn_class_loss: 0.0380 - mrcnn_bbox_loss: 0.0172 - mrcnn_mask_loss: 0.0485 - val_loss: 0.5097 - val_rpn_class_loss: 0.0067 - val_rpn_bbox_loss: 0.3099 - val_mrcnn_class_loss: 0.0673 - val_mrcnn_bbox_loss: 0.0544 - val_mrcnn_mask_loss: 0.0714
# Epoch 61/200
# 100/100 [==============================] - 43s 433ms/step - loss: 0.1214 - rpn_class_loss: 0.0056 - rpn_bbox_loss: 0.0150 - mrcnn_class_loss: 0.0363 - mrcnn_bbox_loss: 0.0159 - mrcnn_mask_loss: 0.0486 - val_loss: 0.7387 - val_rpn_class_loss: 0.0113 - val_rpn_bbox_loss: 0.4503 - val_mrcnn_class_loss: 0.1153 - val_mrcnn_bbox_loss: 0.0659 - val_mrcnn_mask_loss: 0.0959
# Epoch 62/200
# 100/100 [==============================] - 43s 431ms/step - loss: 0.1177 - rpn_class_loss: 0.0057 - rpn_bbox_loss: 0.0142 - mrcnn_class_loss: 0.0349 - mrcnn_bbox_loss: 0.0153 - mrcnn_mask_loss: 0.0475 - val_loss: 0.4768 - val_rpn_class_loss: 0.0071 - val_rpn_bbox_loss: 0.2686 - val_mrcnn_class_loss: 0.0969 - val_mrcnn_bbox_loss: 0.0381 - val_mrcnn_mask_loss: 0.0660
# Epoch 63/200
# 100/100 [==============================] - 44s 436ms/step - loss: 0.1172 - rpn_class_loss: 0.0056 - rpn_bbox_loss: 0.0146 - mrcnn_class_loss: 0.0342 - mrcnn_bbox_loss: 0.0157 - mrcnn_mask_loss: 0.0470 - val_loss: 0.6158 - val_rpn_class_loss: 0.0091 - val_rpn_bbox_loss: 0.3726 - val_mrcnn_class_loss: 0.0959 - val_mrcnn_bbox_loss: 0.0648 - val_mrcnn_mask_loss: 0.0735
# Epoch 64/200
# 100/100 [==============================] - 43s 434ms/step - loss: 0.1143 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.0127 - mrcnn_class_loss: 0.0334 - mrcnn_bbox_loss: 0.0157 - mrcnn_mask_loss: 0.0469 - val_loss: 0.6182 - val_rpn_class_loss: 0.0076 - val_rpn_bbox_loss: 0.3095 - val_mrcnn_class_loss: 0.0998 - val_mrcnn_bbox_loss: 0.0702 - val_mrcnn_mask_loss: 0.1311
# Epoch 65/200
# 100/100 [==============================] - 43s 433ms/step - loss: 0.1124 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.0134 - mrcnn_class_loss: 0.0316 - mrcnn_bbox_loss: 0.0146 - mrcnn_mask_loss: 0.0473 - val_loss: 0.5227 - val_rpn_class_loss: 0.0064 - val_rpn_bbox_loss: 0.3153 - val_mrcnn_class_loss: 0.0769 - val_mrcnn_bbox_loss: 0.0500 - val_mrcnn_mask_loss: 0.0741
# Epoch 66/200
# 100/100 [==============================] - 43s 433ms/step - loss: 0.1133 - rpn_class_loss: 0.0056 - rpn_bbox_loss: 0.0137 - mrcnn_class_loss: 0.0321 - mrcnn_bbox_loss: 0.0152 - mrcnn_mask_loss: 0.0468 - val_loss: 0.3934 - val_rpn_class_loss: 0.0054 - val_rpn_bbox_loss: 0.2339 - val_mrcnn_class_loss: 0.0722 - val_mrcnn_bbox_loss: 0.0339 - val_mrcnn_mask_loss: 0.0479
# Epoch 67/200
# 100/100 [==============================] - 43s 431ms/step - loss: 0.1100 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.0115 - mrcnn_class_loss: 0.0328 - mrcnn_bbox_loss: 0.0143 - mrcnn_mask_loss: 0.0462 - val_loss: 0.5666 - val_rpn_class_loss: 0.0072 - val_rpn_bbox_loss: 0.3632 - val_mrcnn_class_loss: 0.0829 - val_mrcnn_bbox_loss: 0.0409 - val_mrcnn_mask_loss: 0.0723
# Epoch 68/200
# 100/100 [==============================] - 43s 430ms/step - loss: 0.1145 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.0132 - mrcnn_class_loss: 0.0341 - mrcnn_bbox_loss: 0.0152 - mrcnn_mask_loss: 0.0467 - val_loss: 0.4249 - val_rpn_class_loss: 0.0062 - val_rpn_bbox_loss: 0.2725 - val_mrcnn_class_loss: 0.0604 - val_mrcnn_bbox_loss: 0.0296 - val_mrcnn_mask_loss: 0.0562
# Epoch 69/200
# 100/100 [==============================] - 43s 435ms/step - loss: 0.1143 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.0130 - mrcnn_class_loss: 0.0338 - mrcnn_bbox_loss: 0.0152 - mrcnn_mask_loss: 0.0468 - val_loss: 0.6600 - val_rpn_class_loss: 0.0135 - val_rpn_bbox_loss: 0.4868 - val_mrcnn_class_loss: 0.0687 - val_mrcnn_bbox_loss: 0.0429 - val_mrcnn_mask_loss: 0.0481
# Epoch 70/200
# 100/100 [==============================] - 43s 431ms/step - loss: 0.1114 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.0121 - mrcnn_class_loss: 0.0351 - mrcnn_bbox_loss: 0.0142 - mrcnn_mask_loss: 0.0445 - val_loss: 0.5257 - val_rpn_class_loss: 0.0077 - val_rpn_bbox_loss: 0.2998 - val_mrcnn_class_loss: 0.0927 - val_mrcnn_bbox_loss: 0.0424 - val_mrcnn_mask_loss: 0.0830
# Epoch 71/200
# 100/100 [==============================] - 43s 431ms/step - loss: 0.1064 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.0112 - mrcnn_class_loss: 0.0298 - mrcnn_bbox_loss: 0.0147 - mrcnn_mask_loss: 0.0455 - val_loss: 0.6230 - val_rpn_class_loss: 0.0079 - val_rpn_bbox_loss: 0.3135 - val_mrcnn_class_loss: 0.1242 - val_mrcnn_bbox_loss: 0.0566 - val_mrcnn_mask_loss: 0.1208
# Epoch 72/200
# 100/100 [==============================] - 43s 433ms/step - loss: 0.1069 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.0100 - mrcnn_class_loss: 0.0329 - mrcnn_bbox_loss: 0.0141 - mrcnn_mask_loss: 0.0448 - val_loss: 0.5917 - val_rpn_class_loss: 0.0082 - val_rpn_bbox_loss: 0.3418 - val_mrcnn_class_loss: 0.1068 - val_mrcnn_bbox_loss: 0.0560 - val_mrcnn_mask_loss: 0.0789
# Epoch 73/200
# 100/100 [==============================] - 43s 434ms/step - loss: 0.1119 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.0120 - mrcnn_class_loss: 0.0330 - mrcnn_bbox_loss: 0.0150 - mrcnn_mask_loss: 0.0466 - val_loss: 0.4615 - val_rpn_class_loss: 0.0072 - val_rpn_bbox_loss: 0.2146 - val_mrcnn_class_loss: 0.1104 - val_mrcnn_bbox_loss: 0.0576 - val_mrcnn_mask_loss: 0.0716
# Epoch 74/200
# 100/100 [==============================] - 43s 432ms/step - loss: 0.1080 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.0107 - mrcnn_class_loss: 0.0310 - mrcnn_bbox_loss: 0.0143 - mrcnn_mask_loss: 0.0467 - val_loss: 0.5676 - val_rpn_class_loss: 0.0074 - val_rpn_bbox_loss: 0.2815 - val_mrcnn_class_loss: 0.1007 - val_mrcnn_bbox_loss: 0.0713 - val_mrcnn_mask_loss: 0.1067
# Epoch 75/200
# 100/100 [==============================] - 44s 437ms/step - loss: 0.1142 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.0119 - mrcnn_class_loss: 0.0345 - mrcnn_bbox_loss: 0.0144 - mrcnn_mask_loss: 0.0483 - val_loss: 0.6971 - val_rpn_class_loss: 0.0118 - val_rpn_bbox_loss: 0.4349 - val_mrcnn_class_loss: 0.1136 - val_mrcnn_bbox_loss: 0.0548 - val_mrcnn_mask_loss: 0.0820
# Epoch 76/200
# 100/100 [==============================] - 43s 434ms/step - loss: 0.1059 - rpn_class_loss: 0.0049 - rpn_bbox_loss: 0.0110 - mrcnn_class_loss: 0.0315 - mrcnn_bbox_loss: 0.0136 - mrcnn_mask_loss: 0.0450 - val_loss: 0.5646 - val_rpn_class_loss: 0.0088 - val_rpn_bbox_loss: 0.3264 - val_mrcnn_class_loss: 0.0986 - val_mrcnn_bbox_loss: 0.0518 - val_mrcnn_mask_loss: 0.0790
# Epoch 77/200
# 100/100 [==============================] - 43s 431ms/step - loss: 0.1044 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.0104 - mrcnn_class_loss: 0.0300 - mrcnn_bbox_loss: 0.0133 - mrcnn_mask_loss: 0.0456 - val_loss: 0.3632 - val_rpn_class_loss: 0.0083 - val_rpn_bbox_loss: 0.2415 - val_mrcnn_class_loss: 0.0446 - val_mrcnn_bbox_loss: 0.0246 - val_mrcnn_mask_loss: 0.0441
# Epoch 78/200
# 100/100 [==============================] - 43s 430ms/step - loss: 0.1134 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.0095 - mrcnn_class_loss: 0.0368 - mrcnn_bbox_loss: 0.0146 - mrcnn_mask_loss: 0.0473 - val_loss: 0.6468 - val_rpn_class_loss: 0.0093 - val_rpn_bbox_loss: 0.3919 - val_mrcnn_class_loss: 0.0808 - val_mrcnn_bbox_loss: 0.0590 - val_mrcnn_mask_loss: 0.1059
# Epoch 79/200
# 100/100 [==============================] - 43s 432ms/step - loss: 0.1046 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.0088 - mrcnn_class_loss: 0.0336 - mrcnn_bbox_loss: 0.0133 - mrcnn_mask_loss: 0.0442 - val_loss: 0.5190 - val_rpn_class_loss: 0.0074 - val_rpn_bbox_loss: 0.2850 - val_mrcnn_class_loss: 0.0919 - val_mrcnn_bbox_loss: 0.0552 - val_mrcnn_mask_loss: 0.0795
# Epoch 80/200
# 100/100 [==============================] - 43s 431ms/step - loss: 0.1000 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.0092 - mrcnn_class_loss: 0.0291 - mrcnn_bbox_loss: 0.0129 - mrcnn_mask_loss: 0.0439 - val_loss: 0.6185 - val_rpn_class_loss: 0.0116 - val_rpn_bbox_loss: 0.4136 - val_mrcnn_class_loss: 0.0783 - val_mrcnn_bbox_loss: 0.0457 - val_mrcnn_mask_loss: 0.0693
# Epoch 81/200
# 100/100 [==============================] - 43s 433ms/step - loss: 0.1055 - rpn_class_loss: 0.0047 - rpn_bbox_loss: 0.0111 - mrcnn_class_loss: 0.0312 - mrcnn_bbox_loss: 0.0132 - mrcnn_mask_loss: 0.0453 - val_loss: 0.5825 - val_rpn_class_loss: 0.0055 - val_rpn_bbox_loss: 0.2619 - val_mrcnn_class_loss: 0.0948 - val_mrcnn_bbox_loss: 0.0660 - val_mrcnn_mask_loss: 0.1543
# Epoch 82/200
# 100/100 [==============================] - 43s 430ms/step - loss: 0.1053 - rpn_class_loss: 0.0049 - rpn_bbox_loss: 0.0088 - mrcnn_class_loss: 0.0319 - mrcnn_bbox_loss: 0.0136 - mrcnn_mask_loss: 0.0461 - val_loss: 0.6416 - val_rpn_class_loss: 0.0103 - val_rpn_bbox_loss: 0.4131 - val_mrcnn_class_loss: 0.0881 - val_mrcnn_bbox_loss: 0.0464 - val_mrcnn_mask_loss: 0.0837
# Epoch 83/200
# 100/100 [==============================] - 43s 432ms/step - loss: 0.1010 - rpn_class_loss: 0.0049 - rpn_bbox_loss: 0.0083 - mrcnn_class_loss: 0.0312 - mrcnn_bbox_loss: 0.0126 - mrcnn_mask_loss: 0.0441 - val_loss: 0.5186 - val_rpn_class_loss: 0.0079 - val_rpn_bbox_loss: 0.2740 - val_mrcnn_class_loss: 0.0801 - val_mrcnn_bbox_loss: 0.0579 - val_mrcnn_mask_loss: 0.0986
# Epoch 84/200
# 100/100 [==============================] - 43s 431ms/step - loss: 0.0986 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.0084 - mrcnn_class_loss: 0.0277 - mrcnn_bbox_loss: 0.0127 - mrcnn_mask_loss: 0.0450 - val_loss: 0.6089 - val_rpn_class_loss: 0.0072 - val_rpn_bbox_loss: 0.3363 - val_mrcnn_class_loss: 0.1207 - val_mrcnn_bbox_loss: 0.0570 - val_mrcnn_mask_loss: 0.0876
# Epoch 85/200
# 100/100 [==============================] - 43s 433ms/step - loss: 0.0978 - rpn_class_loss: 0.0046 - rpn_bbox_loss: 0.0092 - mrcnn_class_loss: 0.0289 - mrcnn_bbox_loss: 0.0120 - mrcnn_mask_loss: 0.0432 - val_loss: 0.5255 - val_rpn_class_loss: 0.0060 - val_rpn_bbox_loss: 0.2973 - val_mrcnn_class_loss: 0.0707 - val_mrcnn_bbox_loss: 0.0527 - val_mrcnn_mask_loss: 0.0988
# Epoch 86/200
# 100/100 [==============================] - 43s 435ms/step - loss: 0.0960 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.0083 - mrcnn_class_loss: 0.0272 - mrcnn_bbox_loss: 0.0120 - mrcnn_mask_loss: 0.0441 - val_loss: 0.5272 - val_rpn_class_loss: 0.0073 - val_rpn_bbox_loss: 0.3187 - val_mrcnn_class_loss: 0.0669 - val_mrcnn_bbox_loss: 0.0477 - val_mrcnn_mask_loss: 0.0865
# Epoch 87/200
# 100/100 [==============================] - 43s 433ms/step - loss: 0.0977 - rpn_class_loss: 0.0044 - rpn_bbox_loss: 0.0083 - mrcnn_class_loss: 0.0276 - mrcnn_bbox_loss: 0.0125 - mrcnn_mask_loss: 0.0449 - val_loss: 0.5455 - val_rpn_class_loss: 0.0089 - val_rpn_bbox_loss: 0.3600 - val_mrcnn_class_loss: 0.0731 - val_mrcnn_bbox_loss: 0.0431 - val_mrcnn_mask_loss: 0.0605
# Epoch 88/200
# 100/100 [==============================] - 43s 432ms/step - loss: 0.0944 - rpn_class_loss: 0.0046 - rpn_bbox_loss: 0.0066 - mrcnn_class_loss: 0.0279 - mrcnn_bbox_loss: 0.0123 - mrcnn_mask_loss: 0.0431 - val_loss: 0.4951 - val_rpn_class_loss: 0.0069 - val_rpn_bbox_loss: 0.2775 - val_mrcnn_class_loss: 0.0819 - val_mrcnn_bbox_loss: 0.0495 - val_mrcnn_mask_loss: 0.0793
# Epoch 89/200
# 100/100 [==============================] - 43s 432ms/step - loss: 0.0957 - rpn_class_loss: 0.0044 - rpn_bbox_loss: 0.0076 - mrcnn_class_loss: 0.0281 - mrcnn_bbox_loss: 0.0121 - mrcnn_mask_loss: 0.0433 - val_loss: 0.4933 - val_rpn_class_loss: 0.0056 - val_rpn_bbox_loss: 0.2526 - val_mrcnn_class_loss: 0.0869 - val_mrcnn_bbox_loss: 0.0640 - val_mrcnn_mask_loss: 0.0841
# Epoch 90/200
# 100/100 [==============================] - 43s 429ms/step - loss: 0.0929 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.0074 - mrcnn_class_loss: 0.0270 - mrcnn_bbox_loss: 0.0115 - mrcnn_mask_loss: 0.0425 - val_loss: 0.6093 - val_rpn_class_loss: 0.0067 - val_rpn_bbox_loss: 0.3450 - val_mrcnn_class_loss: 0.0838 - val_mrcnn_bbox_loss: 0.0707 - val_mrcnn_mask_loss: 0.1032
# Epoch 91/200
# 100/100 [==============================] - 44s 435ms/step - loss: 0.0967 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.0073 - mrcnn_class_loss: 0.0277 - mrcnn_bbox_loss: 0.0121 - mrcnn_mask_loss: 0.0451 - val_loss: 0.5232 - val_rpn_class_loss: 0.0053 - val_rpn_bbox_loss: 0.2674 - val_mrcnn_class_loss: 0.0939 - val_mrcnn_bbox_loss: 0.0631 - val_mrcnn_mask_loss: 0.0935
# Epoch 92/200
# 100/100 [==============================] - 43s 432ms/step - loss: 0.0960 - rpn_class_loss: 0.0044 - rpn_bbox_loss: 0.0072 - mrcnn_class_loss: 0.0294 - mrcnn_bbox_loss: 0.0119 - mrcnn_mask_loss: 0.0431 - val_loss: 0.5468 - val_rpn_class_loss: 0.0072 - val_rpn_bbox_loss: 0.3245 - val_mrcnn_class_loss: 0.0909 - val_mrcnn_bbox_loss: 0.0529 - val_mrcnn_mask_loss: 0.0712
# Epoch 93/200
# 100/100 [==============================] - 43s 434ms/step - loss: 0.0970 - rpn_class_loss: 0.0042 - rpn_bbox_loss: 0.0080 - mrcnn_class_loss: 0.0280 - mrcnn_bbox_loss: 0.0125 - mrcnn_mask_loss: 0.0443 - val_loss: 0.4097 - val_rpn_class_loss: 0.0064 - val_rpn_bbox_loss: 0.2850 - val_mrcnn_class_loss: 0.0520 - val_mrcnn_bbox_loss: 0.0254 - val_mrcnn_mask_loss: 0.0410
# Epoch 94/200
# 100/100 [==============================] - 43s 432ms/step - loss: 0.0921 - rpn_class_loss: 0.0042 - rpn_bbox_loss: 0.0070 - mrcnn_class_loss: 0.0263 - mrcnn_bbox_loss: 0.0115 - mrcnn_mask_loss: 0.0431 - val_loss: 0.4360 - val_rpn_class_loss: 0.0060 - val_rpn_bbox_loss: 0.2132 - val_mrcnn_class_loss: 0.1078 - val_mrcnn_bbox_loss: 0.0416 - val_mrcnn_mask_loss: 0.0673
# Epoch 95/200
# 100/100 [==============================] - 43s 432ms/step - loss: 0.0931 - rpn_class_loss: 0.0042 - rpn_bbox_loss: 0.0071 - mrcnn_class_loss: 0.0264 - mrcnn_bbox_loss: 0.0123 - mrcnn_mask_loss: 0.0432 - val_loss: 0.4812 - val_rpn_class_loss: 0.0067 - val_rpn_bbox_loss: 0.2868 - val_mrcnn_class_loss: 0.0773 - val_mrcnn_bbox_loss: 0.0447 - val_mrcnn_mask_loss: 0.0658
# Epoch 96/200
# 100/100 [==============================] - 43s 433ms/step - loss: 0.0921 - rpn_class_loss: 0.0042 - rpn_bbox_loss: 0.0073 - mrcnn_class_loss: 0.0271 - mrcnn_bbox_loss: 0.0114 - mrcnn_mask_loss: 0.0422 - val_loss: 0.5922 - val_rpn_class_loss: 0.0077 - val_rpn_bbox_loss: 0.3241 - val_mrcnn_class_loss: 0.1212 - val_mrcnn_bbox_loss: 0.0554 - val_mrcnn_mask_loss: 0.0838
# Epoch 97/200
# 100/100 [==============================] - 43s 432ms/step - loss: 0.0961 - rpn_class_loss: 0.0043 - rpn_bbox_loss: 0.0065 - mrcnn_class_loss: 0.0282 - mrcnn_bbox_loss: 0.0118 - mrcnn_mask_loss: 0.0453 - val_loss: 0.4295 - val_rpn_class_loss: 0.0059 - val_rpn_bbox_loss: 0.2284 - val_mrcnn_class_loss: 0.0876 - val_mrcnn_bbox_loss: 0.0434 - val_mrcnn_mask_loss: 0.0642
# Epoch 98/200
# 100/100 [==============================] - 43s 432ms/step - loss: 0.0928 - rpn_class_loss: 0.0043 - rpn_bbox_loss: 0.0068 - mrcnn_class_loss: 0.0266 - mrcnn_bbox_loss: 0.0116 - mrcnn_mask_loss: 0.0435 - val_loss: 0.6785 - val_rpn_class_loss: 0.0063 - val_rpn_bbox_loss: 0.3144 - val_mrcnn_class_loss: 0.1421 - val_mrcnn_bbox_loss: 0.0703 - val_mrcnn_mask_loss: 0.1453
# Epoch 99/200
# 100/100 [==============================] - 43s 434ms/step - loss: 0.0918 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.0067 - mrcnn_class_loss: 0.0281 - mrcnn_bbox_loss: 0.0110 - mrcnn_mask_loss: 0.0420 - val_loss: 0.5404 - val_rpn_class_loss: 0.0074 - val_rpn_bbox_loss: 0.3554 - val_mrcnn_class_loss: 0.0746 - val_mrcnn_bbox_loss: 0.0362 - val_mrcnn_mask_loss: 0.0668
# Epoch 100/200
# 100/100 [==============================] - 43s 433ms/step - loss: 0.0895 - rpn_class_loss: 0.0043 - rpn_bbox_loss: 0.0063 - mrcnn_class_loss: 0.0257 - mrcnn_bbox_loss: 0.0112 - mrcnn_mask_loss: 0.0420 - val_loss: 0.5838 - val_rpn_class_loss: 0.0075 - val_rpn_bbox_loss: 0.3390 - val_mrcnn_class_loss: 0.0894 - val_mrcnn_bbox_loss: 0.0614 - val_mrcnn_mask_loss: 0.0864
# Epoch 101/200
# 100/100 [==============================] - 43s 433ms/step - loss: 0.0873 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.0061 - mrcnn_class_loss: 0.0247 - mrcnn_bbox_loss: 0.0110 - mrcnn_mask_loss: 0.0415 - val_loss: 0.4841 - val_rpn_class_loss: 0.0059 - val_rpn_bbox_loss: 0.2397 - val_mrcnn_class_loss: 0.0892 - val_mrcnn_bbox_loss: 0.0614 - val_mrcnn_mask_loss: 0.0879
# Epoch 102/200
# 100/100 [==============================] - 43s 434ms/step - loss: 0.0927 - rpn_class_loss: 0.0043 - rpn_bbox_loss: 0.0059 - mrcnn_class_loss: 0.0283 - mrcnn_bbox_loss: 0.0116 - mrcnn_mask_loss: 0.0425 - val_loss: 0.5728 - val_rpn_class_loss: 0.0084 - val_rpn_bbox_loss: 0.3281 - val_mrcnn_class_loss: 0.1295 - val_mrcnn_bbox_loss: 0.0472 - val_mrcnn_mask_loss: 0.0597
# Epoch 103/200
# 100/100 [==============================] - 43s 432ms/step - loss: 0.0918 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.0056 - mrcnn_class_loss: 0.0273 - mrcnn_bbox_loss: 0.0110 - mrcnn_mask_loss: 0.0438 - val_loss: 0.6084 - val_rpn_class_loss: 0.0070 - val_rpn_bbox_loss: 0.3061 - val_mrcnn_class_loss: 0.1305 - val_mrcnn_bbox_loss: 0.0623 - val_mrcnn_mask_loss: 0.1025
# Epoch 104/200
# 100/100 [==============================] - 44s 437ms/step - loss: 0.0861 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.0055 - mrcnn_class_loss: 0.0249 - mrcnn_bbox_loss: 0.0108 - mrcnn_mask_loss: 0.0408 - val_loss: 0.8677 - val_rpn_class_loss: 0.0138 - val_rpn_bbox_loss: 0.4784 - val_mrcnn_class_loss: 0.1253 - val_mrcnn_bbox_loss: 0.0789 - val_mrcnn_mask_loss: 0.1712
# ...
# Epoch 160/200
# 100/100 [==============================] - 44s 436ms/step - loss: 0.0740 - rpn_class_loss: 0.0030 - rpn_bbox_loss: 0.0030 - mrcnn_class_loss: 0.0202 - mrcnn_bbox_loss: 0.0082 - mrcnn_mask_loss: 0.0396 - val_loss: 0.6415 - val_rpn_class_loss: 0.0063 - val_rpn_bbox_loss: 0.3256 - val_mrcnn_class_loss: 0.1086 - val_mrcnn_bbox_loss: 0.0685 - val_mrcnn_mask_loss: 0.1325
# Epoch 161/200
# 100/100 [==============================] - 44s 435ms/step - loss: 0.0702 - rpn_class_loss: 0.0027 - rpn_bbox_loss: 0.0031 - mrcnn_class_loss: 0.0194 - mrcnn_bbox_loss: 0.0078 - mrcnn_mask_loss: 0.0371 - val_loss: 0.5377 - val_rpn_class_loss: 0.0050 - val_rpn_bbox_loss: 0.3062 - val_mrcnn_class_loss: 0.0806 - val_mrcnn_bbox_loss: 0.0438 - val_mrcnn_mask_loss: 0.1022
# Epoch 162/200
# 100/100 [==============================] - 43s 434ms/step - loss: 0.0754 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.0032 - mrcnn_class_loss: 0.0217 - mrcnn_bbox_loss: 0.0086 - mrcnn_mask_loss: 0.0389 - val_loss: 0.5217 - val_rpn_class_loss: 0.0062 - val_rpn_bbox_loss: 0.3449 - val_mrcnn_class_loss: 0.0675 - val_mrcnn_bbox_loss: 0.0358 - val_mrcnn_mask_loss: 0.0673
# Epoch 163/200
# 100/100 [==============================] - 44s 435ms/step - loss: 0.0724 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.0033 - mrcnn_class_loss: 0.0208 - mrcnn_bbox_loss: 0.0082 - mrcnn_mask_loss: 0.0374 - val_loss: 0.5039 - val_rpn_class_loss: 0.0057 - val_rpn_bbox_loss: 0.3225 - val_mrcnn_class_loss: 0.0672 - val_mrcnn_bbox_loss: 0.0338 - val_mrcnn_mask_loss: 0.0747
# Epoch 164/200
# 100/100 [==============================] - 43s 434ms/step - loss: 0.0720 - rpn_class_loss: 0.0027 - rpn_bbox_loss: 0.0033 - mrcnn_class_loss: 0.0200 - mrcnn_bbox_loss: 0.0080 - mrcnn_mask_loss: 0.0379 - val_loss: 0.5067 - val_rpn_class_loss: 0.0060 - val_rpn_bbox_loss: 0.3053 - val_mrcnn_class_loss: 0.0775 - val_mrcnn_bbox_loss: 0.0444 - val_mrcnn_mask_loss: 0.0735
# Epoch 165/200
# 100/100 [==============================] - 44s 436ms/step - loss: 0.0725 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.0031 - mrcnn_class_loss: 0.0199 - mrcnn_bbox_loss: 0.0083 - mrcnn_mask_loss: 0.0382 - val_loss: 0.7438 - val_rpn_class_loss: 0.0099 - val_rpn_bbox_loss: 0.4859 - val_mrcnn_class_loss: 0.1265 - val_mrcnn_bbox_loss: 0.0591 - val_mrcnn_mask_loss: 0.0625
# Epoch 166/200
# 100/100 [==============================] - 44s 437ms/step - loss: 0.0710 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.0030 - mrcnn_class_loss: 0.0192 - mrcnn_bbox_loss: 0.0082 - mrcnn_mask_loss: 0.0379 - val_loss: 0.5007 - val_rpn_class_loss: 0.0045 - val_rpn_bbox_loss: 0.2449 - val_mrcnn_class_loss: 0.0813 - val_mrcnn_bbox_loss: 0.0579 - val_mrcnn_mask_loss: 0.1122
# Epoch 167/200
# 100/100 [==============================] - 43s 434ms/step - loss: 0.0700 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.0032 - mrcnn_class_loss: 0.0190 - mrcnn_bbox_loss: 0.0076 - mrcnn_mask_loss: 0.0373 - val_loss: 0.6055 - val_rpn_class_loss: 0.0056 - val_rpn_bbox_loss: 0.3231 - val_mrcnn_class_loss: 0.1257 - val_mrcnn_bbox_loss: 0.0541 - val_mrcnn_mask_loss: 0.0971
# Epoch 168/200
# 100/100 [==============================] - 44s 437ms/step - loss: 0.0686 - rpn_class_loss: 0.0027 - rpn_bbox_loss: 0.0031 - mrcnn_class_loss: 0.0170 - mrcnn_bbox_loss: 0.0079 - mrcnn_mask_loss: 0.0379 - val_loss: 0.6993 - val_rpn_class_loss: 0.0099 - val_rpn_bbox_loss: 0.4310 - val_mrcnn_class_loss: 0.1500 - val_mrcnn_bbox_loss: 0.0401 - val_mrcnn_mask_loss: 0.0682
# Epoch 169/200
# 100/100 [==============================] - 44s 436ms/step - loss: 0.0713 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.0028 - mrcnn_class_loss: 0.0203 - mrcnn_bbox_loss: 0.0077 - mrcnn_mask_loss: 0.0376 - val_loss: 0.4405 - val_rpn_class_loss: 0.0041 - val_rpn_bbox_loss: 0.2371 - val_mrcnn_class_loss: 0.0841 - val_mrcnn_bbox_loss: 0.0489 - val_mrcnn_mask_loss: 0.0663
# Epoch 170/200
# 100/100 [==============================] - 44s 436ms/step - loss: 0.0701 - rpn_class_loss: 0.0026 - rpn_bbox_loss: 0.0032 - mrcnn_class_loss: 0.0185 - mrcnn_bbox_loss: 0.0077 - mrcnn_mask_loss: 0.0381 - val_loss: 0.4773 - val_rpn_class_loss: 0.0052 - val_rpn_bbox_loss: 0.2795 - val_mrcnn_class_loss: 0.1104 - val_mrcnn_bbox_loss: 0.0341 - val_mrcnn_mask_loss: 0.0480
# Epoch 171/200
# 100/100 [==============================] - 43s 435ms/step - loss: 0.0695 - rpn_class_loss: 0.0027 - rpn_bbox_loss: 0.0035 - mrcnn_class_loss: 0.0195 - mrcnn_bbox_loss: 0.0076 - mrcnn_mask_loss: 0.0363 - val_loss: 0.4640 - val_rpn_class_loss: 0.0037 - val_rpn_bbox_loss: 0.2465 - val_mrcnn_class_loss: 0.1071 - val_mrcnn_bbox_loss: 0.0366 - val_mrcnn_mask_loss: 0.0701
# Epoch 172/200
# 100/100 [==============================] - 43s 434ms/step - loss: 0.0715 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.0038 - mrcnn_class_loss: 0.0198 - mrcnn_bbox_loss: 0.0079 - mrcnn_mask_loss: 0.0372 - val_loss: 0.5252 - val_rpn_class_loss: 0.0069 - val_rpn_bbox_loss: 0.3686 - val_mrcnn_class_loss: 0.0720 - val_mrcnn_bbox_loss: 0.0255 - val_mrcnn_mask_loss: 0.0521
# Epoch 173/200
# 100/100 [==============================] - 44s 438ms/step - loss: 0.0681 - rpn_class_loss: 0.0026 - rpn_bbox_loss: 0.0029 - mrcnn_class_loss: 0.0181 - mrcnn_bbox_loss: 0.0076 - mrcnn_mask_loss: 0.0369 - val_loss: 0.3652 - val_rpn_class_loss: 0.0032 - val_rpn_bbox_loss: 0.1884 - val_mrcnn_class_loss: 0.0741 - val_mrcnn_bbox_loss: 0.0349 - val_mrcnn_mask_loss: 0.0646
# Epoch 174/200
# 100/100 [==============================] - 44s 437ms/step - loss: 0.0694 - rpn_class_loss: 0.0027 - rpn_bbox_loss: 0.0029 - mrcnn_class_loss: 0.0193 - mrcnn_bbox_loss: 0.0074 - mrcnn_mask_loss: 0.0371 - val_loss: 0.5573 - val_rpn_class_loss: 0.0066 - val_rpn_bbox_loss: 0.3425 - val_mrcnn_class_loss: 0.0663 - val_mrcnn_bbox_loss: 0.0557 - val_mrcnn_mask_loss: 0.0860
# Epoch 175/200
# 100/100 [==============================] - 44s 437ms/step - loss: 0.0679 - rpn_class_loss: 0.0025 - rpn_bbox_loss: 0.0032 - mrcnn_class_loss: 0.0172 - mrcnn_bbox_loss: 0.0077 - mrcnn_mask_loss: 0.0373 - val_loss: 0.5279 - val_rpn_class_loss: 0.0045 - val_rpn_bbox_loss: 0.2390 - val_mrcnn_class_loss: 0.1391 - val_mrcnn_bbox_loss: 0.0567 - val_mrcnn_mask_loss: 0.0887
# Epoch 176/200
# 100/100 [==============================] - 44s 440ms/step - loss: 0.0702 - rpn_class_loss: 0.0027 - rpn_bbox_loss: 0.0033 - mrcnn_class_loss: 0.0184 - mrcnn_bbox_loss: 0.0076 - mrcnn_mask_loss: 0.0382 - val_loss: 0.5320 - val_rpn_class_loss: 0.0071 - val_rpn_bbox_loss: 0.3737 - val_mrcnn_class_loss: 0.0366 - val_mrcnn_bbox_loss: 0.0398 - val_mrcnn_mask_loss: 0.0749
# Epoch 177/200
# 100/100 [==============================] - 44s 436ms/step - loss: 0.0670 - rpn_class_loss: 0.0026 - rpn_bbox_loss: 0.0031 - mrcnn_class_loss: 0.0171 - mrcnn_bbox_loss: 0.0073 - mrcnn_mask_loss: 0.0368 - val_loss: 0.4672 - val_rpn_class_loss: 0.0046 - val_rpn_bbox_loss: 0.2690 - val_mrcnn_class_loss: 0.0783 - val_mrcnn_bbox_loss: 0.0486 - val_mrcnn_mask_loss: 0.0668
# Epoch 178/200
# 100/100 [==============================] - 44s 438ms/step - loss: 0.0694 - rpn_class_loss: 0.0027 - rpn_bbox_loss: 0.0031 - mrcnn_class_loss: 0.0183 - mrcnn_bbox_loss: 0.0078 - mrcnn_mask_loss: 0.0376 - val_loss: 0.5360 - val_rpn_class_loss: 0.0063 - val_rpn_bbox_loss: 0.3538 - val_mrcnn_class_loss: 0.0634 - val_mrcnn_bbox_loss: 0.0420 - val_mrcnn_mask_loss: 0.0705
# Epoch 179/200
# 100/100 [==============================] - 44s 437ms/step - loss: 0.0666 - rpn_class_loss: 0.0026 - rpn_bbox_loss: 0.0032 - mrcnn_class_loss: 0.0154 - mrcnn_bbox_loss: 0.0073 - mrcnn_mask_loss: 0.0381 - val_loss: 0.5901 - val_rpn_class_loss: 0.0073 - val_rpn_bbox_loss: 0.3477 - val_mrcnn_class_loss: 0.1299 - val_mrcnn_bbox_loss: 0.0408 - val_mrcnn_mask_loss: 0.0644
# Epoch 180/200
# 100/100 [==============================] - 44s 440ms/step - loss: 0.0686 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.0031 - mrcnn_class_loss: 0.0175 - mrcnn_bbox_loss: 0.0077 - mrcnn_mask_loss: 0.0375 - val_loss: 0.5331 - val_rpn_class_loss: 0.0059 - val_rpn_bbox_loss: 0.3270 - val_mrcnn_class_loss: 0.0783 - val_mrcnn_bbox_loss: 0.0417 - val_mrcnn_mask_loss: 0.0802
# Epoch 181/200
# 100/100 [==============================] - 44s 442ms/step - loss: 0.0660 - rpn_class_loss: 0.0025 - rpn_bbox_loss: 0.0035 - mrcnn_class_loss: 0.0166 - mrcnn_bbox_loss: 0.0073 - mrcnn_mask_loss: 0.0361 - val_loss: 0.5195 - val_rpn_class_loss: 0.0075 - val_rpn_bbox_loss: 0.3328 - val_mrcnn_class_loss: 0.0918 - val_mrcnn_bbox_loss: 0.0325 - val_mrcnn_mask_loss: 0.0549
# Epoch 182/200
# 100/100 [==============================] - 44s 438ms/step - loss: 0.0685 - rpn_class_loss: 0.0025 - rpn_bbox_loss: 0.0028 - mrcnn_class_loss: 0.0188 - mrcnn_bbox_loss: 0.0073 - mrcnn_mask_loss: 0.0372 - val_loss: 0.3263 - val_rpn_class_loss: 0.0028 - val_rpn_bbox_loss: 0.1759 - val_mrcnn_class_loss: 0.0502 - val_mrcnn_bbox_loss: 0.0371 - val_mrcnn_mask_loss: 0.0603
# Epoch 183/200
# 100/100 [==============================] - 44s 440ms/step - loss: 0.0686 - rpn_class_loss: 0.0027 - rpn_bbox_loss: 0.0033 - mrcnn_class_loss: 0.0188 - mrcnn_bbox_loss: 0.0075 - mrcnn_mask_loss: 0.0363 - val_loss: 0.5208 - val_rpn_class_loss: 0.0070 - val_rpn_bbox_loss: 0.3572 - val_mrcnn_class_loss: 0.0795 - val_mrcnn_bbox_loss: 0.0264 - val_mrcnn_mask_loss: 0.0507
# Epoch 184/200
# 100/100 [==============================] - 44s 438ms/step - loss: 0.0655 - rpn_class_loss: 0.0025 - rpn_bbox_loss: 0.0032 - mrcnn_class_loss: 0.0168 - mrcnn_bbox_loss: 0.0072 - mrcnn_mask_loss: 0.0358 - val_loss: 0.6422 - val_rpn_class_loss: 0.0080 - val_rpn_bbox_loss: 0.4286 - val_mrcnn_class_loss: 0.0890 - val_mrcnn_bbox_loss: 0.0395 - val_mrcnn_mask_loss: 0.0770
# Epoch 185/200
# 100/100 [==============================] - 44s 436ms/step - loss: 0.0696 - rpn_class_loss: 0.0025 - rpn_bbox_loss: 0.0031 - mrcnn_class_loss: 0.0197 - mrcnn_bbox_loss: 0.0074 - mrcnn_mask_loss: 0.0369 - val_loss: 0.6815 - val_rpn_class_loss: 0.0070 - val_rpn_bbox_loss: 0.3655 - val_mrcnn_class_loss: 0.1481 - val_mrcnn_bbox_loss: 0.0570 - val_mrcnn_mask_loss: 0.1040
# Epoch 186/200
# 100/100 [==============================] - 44s 441ms/step - loss: 0.0653 - rpn_class_loss: 0.0025 - rpn_bbox_loss: 0.0028 - mrcnn_class_loss: 0.0175 - mrcnn_bbox_loss: 0.0073 - mrcnn_mask_loss: 0.0351 - val_loss: 0.6082 - val_rpn_class_loss: 0.0056 - val_rpn_bbox_loss: 0.3027 - val_mrcnn_class_loss: 0.1165 - val_mrcnn_bbox_loss: 0.0654 - val_mrcnn_mask_loss: 0.1181
# Epoch 187/200
# 100/100 [==============================] - 44s 441ms/step - loss: 0.0690 - rpn_class_loss: 0.0024 - rpn_bbox_loss: 0.0027 - mrcnn_class_loss: 0.0191 - mrcnn_bbox_loss: 0.0075 - mrcnn_mask_loss: 0.0373 - val_loss: 0.5169 - val_rpn_class_loss: 0.0060 - val_rpn_bbox_loss: 0.3511 - val_mrcnn_class_loss: 0.0724 - val_mrcnn_bbox_loss: 0.0336 - val_mrcnn_mask_loss: 0.0538
# Epoch 188/200
# 100/100 [==============================] - 44s 440ms/step - loss: 0.0670 - rpn_class_loss: 0.0024 - rpn_bbox_loss: 0.0025 - mrcnn_class_loss: 0.0177 - mrcnn_bbox_loss: 0.0074 - mrcnn_mask_loss: 0.0370 - val_loss: 0.6039 - val_rpn_class_loss: 0.0085 - val_rpn_bbox_loss: 0.3831 - val_mrcnn_class_loss: 0.0831 - val_mrcnn_bbox_loss: 0.0482 - val_mrcnn_mask_loss: 0.0810
# Epoch 189/200
# 100/100 [==============================] - 44s 440ms/step - loss: 0.0688 - rpn_class_loss: 0.0025 - rpn_bbox_loss: 0.0026 - mrcnn_class_loss: 0.0196 - mrcnn_bbox_loss: 0.0074 - mrcnn_mask_loss: 0.0367 - val_loss: 0.6058 - val_rpn_class_loss: 0.0059 - val_rpn_bbox_loss: 0.3365 - val_mrcnn_class_loss: 0.1060 - val_mrcnn_bbox_loss: 0.0638 - val_mrcnn_mask_loss: 0.0935
# Epoch 190/200
# 100/100 [==============================] - 44s 438ms/step - loss: 0.0676 - rpn_class_loss: 0.0024 - rpn_bbox_loss: 0.0031 - mrcnn_class_loss: 0.0170 - mrcnn_bbox_loss: 0.0077 - mrcnn_mask_loss: 0.0374 - val_loss: 0.6131 - val_rpn_class_loss: 0.0065 - val_rpn_bbox_loss: 0.3579 - val_mrcnn_class_loss: 0.0978 - val_mrcnn_bbox_loss: 0.0502 - val_mrcnn_mask_loss: 0.1008
# Epoch 191/200
# 100/100 [==============================] - 44s 437ms/step - loss: 0.0679 - rpn_class_loss: 0.0023 - rpn_bbox_loss: 0.0030 - mrcnn_class_loss: 0.0178 - mrcnn_bbox_loss: 0.0075 - mrcnn_mask_loss: 0.0373 - val_loss: 0.6125 - val_rpn_class_loss: 0.0062 - val_rpn_bbox_loss: 0.3401 - val_mrcnn_class_loss: 0.1186 - val_mrcnn_bbox_loss: 0.0431 - val_mrcnn_mask_loss: 0.1045
# Epoch 192/200
# 100/100 [==============================] - 44s 439ms/step - loss: 0.0639 - rpn_class_loss: 0.0024 - rpn_bbox_loss: 0.0024 - mrcnn_class_loss: 0.0167 - mrcnn_bbox_loss: 0.0065 - mrcnn_mask_loss: 0.0359 - val_loss: 0.4807 - val_rpn_class_loss: 0.0044 - val_rpn_bbox_loss: 0.2583 - val_mrcnn_class_loss: 0.0929 - val_mrcnn_bbox_loss: 0.0381 - val_mrcnn_mask_loss: 0.0870
# Epoch 193/200
# 100/100 [==============================] - 44s 436ms/step - loss: 0.0669 - rpn_class_loss: 0.0025 - rpn_bbox_loss: 0.0028 - mrcnn_class_loss: 0.0178 - mrcnn_bbox_loss: 0.0071 - mrcnn_mask_loss: 0.0368 - val_loss: 0.4416 - val_rpn_class_loss: 0.0033 - val_rpn_bbox_loss: 0.2439 - val_mrcnn_class_loss: 0.0955 - val_mrcnn_bbox_loss: 0.0379 - val_mrcnn_mask_loss: 0.0611
# Epoch 194/200
# 100/100 [==============================] - 44s 440ms/step - loss: 0.0682 - rpn_class_loss: 0.0024 - rpn_bbox_loss: 0.0030 - mrcnn_class_loss: 0.0188 - mrcnn_bbox_loss: 0.0070 - mrcnn_mask_loss: 0.0371 - val_loss: 0.4004 - val_rpn_class_loss: 0.0044 - val_rpn_bbox_loss: 0.2241 - val_mrcnn_class_loss: 0.0489 - val_mrcnn_bbox_loss: 0.0517 - val_mrcnn_mask_loss: 0.0713
# Epoch 195/200
# 100/100 [==============================] - 44s 438ms/step - loss: 0.0632 - rpn_class_loss: 0.0023 - rpn_bbox_loss: 0.0028 - mrcnn_class_loss: 0.0161 - mrcnn_bbox_loss: 0.0066 - mrcnn_mask_loss: 0.0353 - val_loss: 0.4865 - val_rpn_class_loss: 0.0052 - val_rpn_bbox_loss: 0.2972 - val_mrcnn_class_loss: 0.0924 - val_mrcnn_bbox_loss: 0.0372 - val_mrcnn_mask_loss: 0.0545
# Epoch 196/200
# 100/100 [==============================] - 44s 437ms/step - loss: 0.0700 - rpn_class_loss: 0.0024 - rpn_bbox_loss: 0.0026 - mrcnn_class_loss: 0.0200 - mrcnn_bbox_loss: 0.0072 - mrcnn_mask_loss: 0.0378 - val_loss: 0.5762 - val_rpn_class_loss: 0.0062 - val_rpn_bbox_loss: 0.3513 - val_mrcnn_class_loss: 0.1014 - val_mrcnn_bbox_loss: 0.0571 - val_mrcnn_mask_loss: 0.0603
# Epoch 197/200
# 100/100 [==============================] - 44s 435ms/step - loss: 0.0652 - rpn_class_loss: 0.0022 - rpn_bbox_loss: 0.0028 - mrcnn_class_loss: 0.0174 - mrcnn_bbox_loss: 0.0070 - mrcnn_mask_loss: 0.0358 - val_loss: 0.5705 - val_rpn_class_loss: 0.0062 - val_rpn_bbox_loss: 0.3074 - val_mrcnn_class_loss: 0.0857 - val_mrcnn_bbox_loss: 0.0601 - val_mrcnn_mask_loss: 0.1112
# Epoch 198/200
# 100/100 [==============================] - 44s 438ms/step - loss: 0.0677 - rpn_class_loss: 0.0021 - rpn_bbox_loss: 0.0029 - mrcnn_class_loss: 0.0204 - mrcnn_bbox_loss: 0.0067 - mrcnn_mask_loss: 0.0356 - val_loss: 0.7824 - val_rpn_class_loss: 0.0102 - val_rpn_bbox_loss: 0.5279 - val_mrcnn_class_loss: 0.1077 - val_mrcnn_bbox_loss: 0.0593 - val_mrcnn_mask_loss: 0.0773
# Epoch 199/200
# 100/100 [==============================] - 44s 437ms/step - loss: 0.0646 - rpn_class_loss: 0.0024 - rpn_bbox_loss: 0.0026 - mrcnn_class_loss: 0.0176 - mrcnn_bbox_loss: 0.0068 - mrcnn_mask_loss: 0.0352 - val_loss: 0.5047 - val_rpn_class_loss: 0.0059 - val_rpn_bbox_loss: 0.3059 - val_mrcnn_class_loss: 0.0789 - val_mrcnn_bbox_loss: 0.0376 - val_mrcnn_mask_loss: 0.0764
# Epoch 200/200
# 100/100 [==============================] - 44s 437ms/step - loss: 0.0647 - rpn_class_loss: 0.0024 - rpn_bbox_loss: 0.0026 - mrcnn_class_loss: 0.0178 - mrcnn_bbox_loss: 0.0069 - mrcnn_mask_loss: 0.0350 - val_loss: 0.6018 - val_rpn_class_loss: 0.0056 - val_rpn_bbox_loss: 0.3638 - val_mrcnn_class_loss: 0.1000 - val_mrcnn_bbox_loss: 0.0497 - val_mrcnn_mask_loss: 0.0827

# %%
# Save weights
# Typically not needed because callbacks save after every epoch
# Uncomment to save manually
# model_path = os.path.join(MODEL_DIR, "mask_rcnn_shapes.h5")
# model.keras_model.save_weights(model_path)

# %% [markdown]
# ## Detection

# %%
class InferenceConfig(ShapesConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode="inference", 
                          config=inference_config,
                          model_dir=MODEL_DIR)

# Get path to saved weights
# Either set a specific path or find last trained weights
model_path = os.path.join(ROOT_DIR, "logs/shapes20180830T0227/mask_rcnn_shapes_0200.h5")
#model_path = model.find_last()

# Load trained weights
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# Loading weights from  /models/Mask_RCNN/logs/shapes20180830T0227/mask_rcnn_shapes_0200.h5
# Re-starting from epoch 200

# %%
# Test on a random image
image_id = random.choice(dataset_val.image_ids)
original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
    modellib.load_image_gt(dataset_val, inference_config, 
                           image_id, use_mini_mask=False)

log("original_image", original_image)
log("image_meta", image_meta)
log("gt_class_id", gt_class_id)
log("gt_bbox", gt_bbox)
log("gt_mask", gt_mask)

visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                            dataset_train.class_names, figsize=(8, 8))
# Out:
# original_image           shape: (128, 128, 3)         min:   34.00000  max:  207.00000  uint8
# image_meta               shape: (16,)                 min:    0.00000  max:  128.00000  int64
# gt_class_id              shape: (3,)                  min:    2.00000  max:    3.00000  int32
# gt_bbox                  shape: (3, 4)                min:   11.00000  max:  120.00000  int32
# gt_mask                  shape: (128, 128, 3)         min:    0.00000  max:    1.00000  bool

# %%
# show the structure of mask
mask, class_ids = dataset_val.load_mask(image_id)
print(mask.shape)
# Out:
# (128, 128, 3)

# %%
results = model.detect([original_image], verbose=1)

r = results[0]
visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                            dataset_val.class_names, r['scores'], ax=get_ax())
# Out:
# Processing 1 images
# image                    shape: (128, 128, 3)         min:   34.00000  max:  207.00000  uint8
# molded_images            shape: (1, 128, 128, 3)      min:  -89.70000  max:  103.10000  float64
# image_metas              shape: (1, 16)               min:    0.00000  max:  128.00000  int64
# anchors                  shape: (1, 4092, 4)          min:   -0.71267  max:    1.20874  float32

# %% [markdown]
# ## Evaluation

# %%
# Compute VOC-Style mAP @ IoU=0.5
# Running on 10 images. Increase for better accuracy.
image_ids = np.random.choice(dataset_val.image_ids, 10)
APs = []
for image_id in image_ids:
    # Load image and ground truth data
    image, image_meta, gt_class_id, gt_bbox, gt_mask =\
        modellib.load_image_gt(dataset_val, inference_config,
                               image_id, use_mini_mask=False)
    molded_images = np.expand_dims(modellib.mold_image(image, inference_config), 0)
    # Run object detection
    results = model.detect([image], verbose=0)
    r = results[0]
    # Compute AP
    AP, precisions, recalls, overlaps =\
        utils.compute_ap(gt_bbox, gt_class_id, gt_mask,
                         r["rois"], r["class_ids"], r["scores"], r['masks'])
    APs.append(AP)
    
print("mAP: ", np.mean(APs))
# Out:
# mAP:  1.0
