# %% [markdown]
# # Inspect rocks dataset
# Zhiang Chen, Oct 24, 2018
#
# #### 1. Import libraries

# %%
import camtraps
import matplotlib.pyplot as plt
import os
import sys
import skimage.draw
import pickle
import argparse
import numpy as np
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### 2. Load data

# %%
config = camtraps.CamtrapsConfig()
config.display()
dataset = camtraps.CamtrapsDataset()
dataset.load_camtraps('../../dataset/camtraps', 'train')
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        200
# DETECTION_MIN_CONFIDENCE       0.9
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL                  3
# IMAGE_MAX_DIM                  384
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  384
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [384 384   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0}
# ...

# %% [markdown]
# #### 3. Inspect images

# %%
masks, class_ids = dataset.load_mask(1)
# Out:
# 1
# {'path': '../../dataset/camtraps/train/IMG_0061.JPG', 'annotation_path': '../../dataset/camtraps/train/IMG_0061.npy', 'height': 1536, 'id': 1, 'source': 'camtraps', 'width': 2048}
# 1536 2048 0
# (1536, 2048, 0)
# (0,)

# %%
masks, class_ids = dataset.load_mask(1)
print(dataset.image_reference(12))
index = np.random.randint(0, class_ids.shape[0], 1)[0]
#print(index)
#print(masks.shape)
plt.imshow(masks[:,:,index])
plt.show()
# Out:
# 1
# {'path': '../../dataset/camtraps/train/IMG_0061.JPG', 'annotation_path': '../../dataset/camtraps/train/IMG_0061.npy', 'height': 1536, 'id': 1, 'source': 'camtraps', 'width': 2048}
# 1536 2048 0
# (1536, 2048, 0)
# (0,)
# None
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-7bacdf2d3274> in <module>()
#       1 masks, class_ids = dataset.load_mask(1)
#       2 print(dataset.image_reference(12))
# ----> 3 index = np.random.randint(0, class_ids.shape[0], 1)[0]
#       4 #print(index)
#       5 #print(masks.shape)
#
# mtrand.pyx in mtrand.RandomState.randint()
#
# ValueError: low >= high

# %%
dataset.display_mask(0)

# %%
for i in range(2828):
    image_id = i

    img = dataset.load_image(image_id)
    print(img.shape)
    #plt.imshow(img)
    #plt.show()
    if img.shape != (400,400,3):
        print(i)
        break
    masks, ids = dataset.load_mask(image_id)
    mask = masks.max(2)
    print(mask.shape)
    if mask.shape != (400,400):
        print(i)
        break
    #plt.imshow(mask)
    #plt.show()
# Out:
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# (400, 400, 3)
# (400, 400)
# ...
